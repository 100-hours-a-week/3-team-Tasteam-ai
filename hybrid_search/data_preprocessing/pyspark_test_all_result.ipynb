# %% [markdown]
# ## 어떤 필터링도 적용 안함

# %%
import os, sys
os.environ["SPARK_HOME"] = "/opt/homebrew/opt/apache-spark/libexec"
sys.path.insert(0, os.environ["SPARK_HOME"] + "/python")

# %%
# !pyspark --version
# Out:
# WARNING: Using incubator modules: jdk.incubator.vector
# Welcome to
#       ____              __
#      / __/__  ___ _____/ /__
#     _\ \/ _ \/ _ `/ __/  '_/
#    /___/ .__/\_,_/_/ /_/\_\   version 4.1.1
#       /_/
#
# Using Scala version 2.13.17, OpenJDK 64-Bit Server VM, 21.0.9
# Branch HEAD
# Compiled by user runner on 2026-01-02T11:55:02Z
# Revision c0690c763bafabd08e7079d1137fa0a769a05bae
# Url https://github.com/apache/spark
# Type --help for more information.

# %%
from pyspark.sql import SparkSession

spark = SparkSession.builder.appName("demo").getOrCreate()
# Out:
# WARNING: Using incubator modules: jdk.incubator.vector
# Using Spark's default log4j profile: org/apache/spark/log4j2-defaults.properties
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 26/01/26 10:13:56 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable

# %%
sc = spark.sparkContext

# %%
stopwords = (
    spark.sparkContext
         .textFile("/Users/js/tasteam-aicode-gpu-all-python-process-runtime_for_github/hybrid_search/data_preprocessing/stopwords-ko.txt")
         .collect()
)

stopwords_set = set(stopwords)

# %%
bc_stopwords = spark.sparkContext.broadcast(stopwords_set)

# %%
import re

df = spark.read.option("sep", "\t").option("header", "true").csv("/Users/js/tasteam-aicode-gpu-all-python-process-runtime_for_github/data/kr3.tsv")

rdd = (
    df.select("Review")
      .rdd
      .flatMap(lambda r: re.findall(r"[가-힣A-Za-z0-9]+", r[0]))
      .filter(lambda w: w not in bc_stopwords.value)
      .filter(lambda w: len(w) >= 2)          # 한 글자 제거 (선택)
      .map(lambda w: (w, 1))
      .reduceByKey(lambda a, b: a + b)
)
rdd.collect()
# Out:
# [('돼지고기', 2839),
#  ('쾌적한', 492),
#  ('편이고', 3320),
#  ('인상', 2425),
#  ('알았는데', 3642),
#  ('육향', 334),
#  ('수육이', 657),
#  ('소주를', 534),
#  ('시킨', 4412),
#  ('참고하세요', 1654),
#  ('무난한', 3852),
#  ('순댓국보다', 37),
#  ('않고', 29799),
#  ('친절했음', 124),
#  ('먹음', 5539),
#  ('고기에서', 392),
#  ('별로', 16413),
#  ('없는', 21428),
#  ('순댓국집이죠', 2),
#  ('편리합니다', 89),
#  ('대기인원이', 68),
#  ('주차는', 2796),
#  ('푸짐하다', 446),
#  ('찹쌀순대는', 10),
#  ('않은', 15668),
#  ('하얀', 1468),
#  ('후추', 1327),
#  ('조합해', 39),
#  ('당면이', 254),
#  ('동네에선', 98),
#  ('지금이야', 32),
#  ('힘들어졌다', 12),
#  ('국물을', 2428),
#  ('주문했는데', 5072),
#  ('10분', 1793),
#  ('싶을', 8129),
#  ('미리', 5990),
#  ('지금까지', 2017),
#  ('저녁엔', 387),
#  ('마파', 76),
#  ('냄새', 2679),
#  ('버섯', 3778),
#  ('탕수육에는', 8),
#  ('미흡했으나', 1),
#  ('이미', 5488),
#  ('하여', 1607),
#  ('마파두부가', 113),
#  ('맛있다고', 7543),
#  ('올라와서', 336),
#  ('길었음', 38),
#  ('오래', 6765),
#  ('흔들릴', 9),
#  ('pm710', 1),
#  ('주문한', 4121),
#  ('숟가락을', 181),
#  ('감동은', 318),
#  ('기다려야', 2454),
#  ('신선한', 4128),
#  ('드디어', 3802),
#  ('먹게', 3591),
#  ('먹길래', 120),
#  ('우리도', 155),
#  ('식구', 44),
#  ('티브이에서', 131),
#  ('생각나서', 1528),
#  ('말해서', 230),
#  ('떠오름', 39),
#  ('거란', 173),
#  ('야채가', 1419),
#  ('생각할', 636),
#  ('지난번', 496),
#  ('올린', 1347),
#  ('역해서', 26),
#  ('말림', 10),
#  ('같지', 1139),
#  ('팔아요', 371),
#  ('집에서', 5777),
#  ('포장되니', 6),
#  ('포장', 2778),
#  ('코스와', 77),
#  ('정도만', 556),
#  ('편백', 108),
#  ('찜으로도', 2),
#  ('집이다', 2942),
#  ('짱임', 205),
#  ('읽고', 241),
#  ('고등어봉초밥은', 27),
#  ('비린', 2167),
#  ('생선회는', 430),
#  ('많았고요', 139),
#  ('서비스도', 5598),
#  ('장난', 1625),
#  ('조용한', 2589),
#  ('직원', 3228),
#  ('식당입니다', 1388),
#  ('드시고', 1597),
#  ('나오고', 6405),
#  ('평범한', 4631),
#  ('뚝딱하고', 95),
#  ('매운탕', 1050),
#  ('사서', 1693),
#  ('멍게', 402),
#  ('신선하다', 272),
#  ('식사로', 1318),
#  ('평점이', 1848),
#  ('해물도', 384),
#  ('하나로도', 39),
#  ('그럴', 1629),
#  ('부어서', 413),
#  ('없었습니다', 1220),
#  ('아버지', 272),
#  ('찍어놨어야', 7),
#  ('커피값', 54),
#  ('들어가자마자', 1005),
#  ('공기에', 63),
#  ('조화란', 36),
#  ('메뉴에', 1988),
#  ('차이', 1097),
#  ('곳이고요', 81),
#  ('재미가', 1761),
#  ('방문도', 82),
#  ('시원한', 4091),
#  ('별이', 131),
#  ('반찬도', 3810),
#  ('계란', 5551),
#  ('편이었고', 459),
#  ('사이드', 2846),
#  ('꽤나', 3218),
#  ('있었지만', 2268),
#  ('거겠죠', 215),
#  ('곱도리탕', 28),
#  ('기본으로', 2334),
#  ('사람', 9267),
#  ('서비스', 10791),
#  ('쪄서', 182),
#  ('친절하게', 2684),
#  ('체크', 145),
#  ('되어', 4206),
#  ('직원들', 2214),
#  ('슈크림', 449),
#  ('무난한데', 183),
#  ('재질', 37),
#  ('좋아하면', 754),
#  ('일으킴', 7),
#  ('가리비', 741),
#  ('주꾸미를', 177),
#  ('먹어보는', 1903),
#  ('온다', 479),
#  ('좋아서', 7808),
#  ('집을', 3247),
#  ('추천할만하다', 89),
#  ('대파', 550),
#  ('대박이긴', 2),
#  ('때마다', 10793),
#  ('진하지', 411),
#  ('소스나', 285),
#  ('반찬이', 2315),
#  ('바게트', 2665),
#  ('쌀국수인데', 25),
#  ('반미가', 99),
#  ('민트', 602),
#  ('별로였음', 749),
#  ('사이공이', 14),
#  ('난생처음으로', 8),
#  ('비해서', 1251),
#  ('튀김옷이', 1378),
#  ('낙지로', 32),
#  ('낙지여서', 1),
#  ('편이어서', 514),
#  ('지경이었다', 29),
#  ('샐러드는', 1947),
#  ('매운맛임', 10),
#  ('친절하심만', 1),
#  ('아침식사도', 12),
#  ('재방문', 10707),
#  ('광어', 1451),
#  ('우린', 733),
#  ('썰려서', 69),
#  ('고깃집은', 153),
#  ('짭조름하니', 219),
#  ('세트', 5168),
#  ('맛있었네요', 1063),
#  ('되었어요', 678),
#  ('쉬워요', 145),
#  ('하시던데', 201),
#  ('시스템도', 107),
#  ('인테리어', 4334),
#  ('좌석은', 569),
#  ('먹으려고', 1543),
#  ('끝나서', 111),
#  ('직장인이', 74),
#  ('본점', 1135),
#  ('2층에', 1351),
#  ('음식점이라', 101),
#  ('속을', 688),
#  ('문제는', 859),
#  ('굿이에요', 136),
#  ('먹어야겠어요', 226),
#  ('메뉴도', 5124),
#  ('싶음', 1977),
#  ('줄을', 2054),
#  ('때랑은', 38),
#  ('비교불가다', 3),
#  ('바오', 549),
#  ('하얼빈', 102),
#  ('맥주에', 217),
#  ('평일은', 95),
#  ('6시', 1099),
#  ('일대라', 2),
#  ('길다', 491),
#  ('하긴', 748),
#  ('했지만', 5511),
#  ('중국음식', 194),
#  ('주말', 3533),
#  ('21로', 2),
#  ('군만두는', 631),
#  ('일품이었다', 182),
#  ('하게', 1771),
#  ('중국식', 667),
#  ('무엇인지', 153),
#  ('주차공간이', 601),
#  ('상황에', 139),
#  ('상태에서', 597),
#  ('회식', 584),
#  ('목적으로', 152),
#  ('깔끔하다거나', 4),
#  ('어우러져', 1141),
#  ('푸는', 253),
#  ('점심시간', 1056),
#  ('리필', 1876),
#  ('한자리니', 2),
#  ('배추김치가', 94),
#  ('갈비탕에', 77),
#  ('국물과', 1380),
#  ('채울', 241),
#  ('할인권', 19),
#  ('싶어서', 4250),
#  ('안달', 21),
#  ('여러모로', 1480),
#  ('있긴', 1951),
#  ('1위', 369),
#  ('행해지며', 1),
#  ('선짓국', 124),
#  ('시키지', 827),
#  ('시키지도', 47),
#  ('데에서', 76),
#  ('미안하다거나', 1),
#  ('막국수', 3521),
#  ('다행히도', 208),
#  ('짧은', 576),
#  ('주문이', 1728),
#  ('않았다', 4994),
#  ('기대하고', 2673),
#  ('어우러지는', 499),
#  ('마시고', 2976),
#  ('다음에는', 2976),
#  ('있는데도', 401),
#  ('유지해', 34),
#  ('착하진', 97),
#  ('연하고', 385),
#  ('어머니가', 350),
#  ('손님도', 1224),
#  ('겉절이는', 96),
#  ('합니다', 7299),
#  ('곳인데', 4224),
#  ('방문이에요', 55),
#  ('갖춰야', 33),
#  ('마라탕에', 76),
#  ('고르는', 487),
#  ('커버하고도', 9),
#  ('많았는데', 1099),
#  ('기다려', 543),
#  ('공깃밥도', 246),
#  ('덮밥', 2309),
#  ('원인가', 152),
#  ('한적해요', 10),
#  ('맵다', 655),
#  ('고기보다', 242),
#  ('무료주차되는', 2),
#  ('디지털에서', 2),
#  ('놀라고', 624),
#  ('맘스터치는', 22),
#  ('버거도', 460),
#  ('평일에', 1082),
#  ('길어요', 507),
#  ('낮은', 835),
#  ('들어갔다', 924),
#  ('카페만', 100),
#  ('떠나', 253),
#  ('밀크티도', 364),
#  ('디저트도', 1606),
#  ('친절하세요', 2057),
#  ('매장에서', 1442),
#  ('배달', 1421),
#  ('구석의', 11),
#  ('찾아가기', 449),
#  ('다음갈', 1),
#  ('자세하게', 129),
#  ('깔끔했고요', 36),
#  ('멀리까지', 159),
#  ('웬만한', 1595),
#  ('수저통만', 1),
#  ('루프탑', 557),
#  ('연기가', 325),
#  ('고기로', 414),
#  ('고깃집이에요', 86),
#  ('같더라고요', 1094),
#  ('삼선짜장은', 13),
#  ('음식점이', 579),
#  ('미니코스에', 1),
#  ('일치를', 3),
#  ('테이블인데', 18),
#  ('고갈비', 35),
#  ('1인당', 813),
#  ('닭갈비도', 220),
#  ('드십니다', 21),
#  ('가게인데', 251),
#  ('이곳에서의', 37),
#  ('요소가', 236),
#  ('촉촉해요', 134),
#  ('똑같지', 25),
#  ('지점마다', 169),
#  ('보장되는', 93),
#  ('생각나는', 4713),
#  ('단층', 21),
#  ('숯불', 1317),
#  ('점수를', 530),
#  ('앖음', 1),
#  ('짜장면', 1860),
#  ('맛에는', 122),
#  ('입가심으로', 282),
#  ('홍초', 26),
#  ('특색', 1945),
#  ('중국집으로', 34),
#  ('식재료를', 250),
#  ('잡아줘', 29),
#  ('짬뽕을', 706),
#  ('가려고요', 776),
#  ('백김치랑', 73),
#  ('청국장이나', 8),
#  ('셰이크라는', 3),
#  ('아이스크림', 3693),
#  ('기억나시나요', 2),
#  ('겁니다', 1321),
#  ('쌓이는', 30),
#  ('음료들도', 138),
#  ('디저트가', 1538),
#  ('그에', 1042),
#  ('되기', 287),
#  ('제이플라츠', 1),
#  ('짜리', 144),
#  ('다릅니다', 341),
#  ('않거', 10),
#  ('남는', 2000),
#  ('아침식사가', 16),
#  ('이른', 1033),
#  ('브런치로', 287),
#  ('프랜차이즈라', 60),
#  ('스타벅스가', 54),
#  ('김밥', 3843),
#  ('가봤어요', 828),
#  ('특이하게', 1285),
#  ('말뚝', 19),
#  ('들어갔어요', 1026),
#  ('집에요', 16),
#  ('싶지', 1920),
#  ('다방과', 7),
#  ('인덕션이', 11),
#  ('끝내주네요', 136),
#  ('점심으로', 731),
#  ('저렴해요', 423),
#  ('맛까지', 894),
#  ('무한으로', 256),
#  ('빠르게', 1128),
#  ('스타벅스의', 20),
#  ('상권이', 98),
#  ('출동해봤습니다만', 1),
#  ('든든하고', 409),
#  ('좋아하지만', 810),
#  ('판단', 66),
#  ('나가사키', 348),
#  ('아줌마들', 130),
#  ('여기서만', 278),
#  ('대륭에도', 1),
#  ('먹어봤어요', 957),
#  ('찰지고', 213),
#  ('주스는', 244),
#  ('무한리필로', 215),
#  ('넣어주십니다', 25),
#  ('탕수육인데', 36),
#  ('점에', 216),
#  ('웨이팅은', 2085),
#  ('회사에서', 233),
#  ('막걸리', 2130),
#  ('육전이었는데', 2),
#  ('인간적으로', 137),
#  ('부담', 3081),
#  ('조금만', 1781),
#  ('행사가', 36),
#  ('취향에', 1584),
#  ('에일', 152),
#  ('잔당', 64),
#  ('맥주를', 1511),
#  ('자극적이라', 135),
#  ('티가', 586),
#  ('광고', 222),
#  ('무색하게', 127),
#  ('미디엄', 1079),
#  ('오겠다', 39),
#  ('스프링', 121),
#  ('걸리니', 83),
#  ('나오는데요', 85),
#  ('맛있더라고요', 3450),
#  ('충분할', 285),
#  ('바빠서', 933),
#  ('맛이라', 2721),
#  ('와보니', 96),
#  ('않나', 1052),
#  ('밖에', 3246),
#  ('덥다', 85),
#  ('처음엔', 1891),
#  ('당황했지만', 194),
#  ('물론이고요', 14),
#  ('글을', 544),
#  ('핀잔을', 17),
#  ('가져와야', 60),
#  ('삼겹살을', 511),
#  ('단골들이', 95),
#  ('입맛', 1868),
#  ('비싼데', 861),
#  ('지정해서', 6),
#  ('달아서', 2064),
#  ('매장보다', 48),
#  ('적합해요', 16),
#  ('어른은', 12),
#  ('잡지만', 5),
#  ('가봤을', 60),
#  ('느껴졌습니다', 484),
#  ('할거', 100),
#  ('외에는', 665),
#  ('나가야', 223),
#  ('해온', 61),
#  ('내공', 146),
#  ('말아가며', 3),
#  ('피림프', 1),
#  ('빠네는', 69),
#  ('무난했어요', 482),
#  ('나름', 5748),
#  ('주인이', 543),
#  ('오코노미야키는', 133),
#  ('비교할', 343),
#  ('사진에', 833),
#  ('야채는', 407),
#  ('죽었고', 3),
#  ('24시란', 1),
#  ('신경을', 1019),
#  ('뻑뻑해', 13),
#  ('냄새나고', 283),
#  ('추석에도', 7),
#  ('열더라고요', 3),
#  ('버무려진', 141),
#  ('맛이쪙', 20),
#  ('맛만', 1536),
#  ('보장함', 24),
#  ('맛있기로', 170),
#  ('깔끔해져서', 25),
#  ('깔끔해졌다', 19),
#  ('달콤해요', 47),
#  ('선어회', 37),
#  ('간재미는', 4),
#  ('초장을', 50),
#  ('각각의', 434),
#  ('뜨고', 250),
#  ('양념구이를', 15),
#  ('집이었습니다', 316),
#  ('시원하니', 413),
#  ('유명하다는데', 130),
#  ('먹어봤네요', 158),
#  ('동동', 248),
#  ('느낌이라', 2354),
#  ('생맥주', 535),
#  ('한정식집들', 5),
#  ('사항', 28),
#  ('어울림', 839),
#  ('나만의', 247),
#  ('동태탕도', 10),
#  ('평수는', 6),
#  ('넉넉하다', 117),
#  ('알탕도', 37),
#  ('생선이', 580),
#  ('현지인', 501),
#  ('접시를', 415),
#  ('뺍니다', 91),
#  ('회식으로도', 51),
#  ('시절에', 96),
#  ('타짜', 18),
#  ('찜도', 136),
#  ('맛있도라고요', 4),
#  ('좋겠어요', 1481),
#  ('매운맛은', 585),
#  ('땀이', 139),
#  ('짠맛', 363),
#  ('끝날', 235),
#  ('늘어나', 23),
#  ('고등어조림', 152),
#  ('토핑도', 415),
#  ('좁아서', 1313),
#  ('따뜻국물따뜻면', 1),
#  ('일품이에요', 208),
#  ('정성을', 324),
#  ('가격대는', 1593),
#  ('섬세한', 338),
#  ('쫄깃해서', 536),
#  ('적당합니다', 252),
#  ('여타', 392),
#  ('협소하고', 434),
#  ('끝나면', 209),
#  ('와서는', 114),
#  ('그것도', 1653),
#  ('건너편', 379),
#  ('맛보아도', 13),
#  ('별다를', 96),
#  ('못난이', 48),
#  ('튀김인데', 71),
#  ('돌아도', 7),
#  ('썰어', 755),
#  ('튀김이란', 8),
#  ('다양화가', 2),
#  ('이정희가', 2),
#  ('단골손님이', 51),
#  ('무척', 1829),
#  ('덥습니다', 23),
#  ('매운맛보단', 8),
#  ('고추장과', 82),
#  ('맛이랄까', 481),
#  ('섞은', 665),
#  ('대자가', 42),
#  ('25천', 19),
#  ('메뉴이고요', 6),
#  ('시장에서', 350),
#  ('하필', 252),
#  ('닭내장이냐', 1),
#  ('사라지고', 248),
#  ('간지', 153),
#  ('맛이랑도', 4),
#  ('맛이라서', 400),
#  ('추천이에요', 151),
#  ('나박김치와', 1),
#  ('속도가', 437),
#  ('완벽', 626),
#  ('콜라겐', 79),
#  ('금세', 451),
#  ('입엔', 500),
#  ('겨울이', 137),
#  ('훈훈해요', 4),
#  ('곱창전골', 598),
#  ('누린내', 457),
#  ('특별하지도', 113),
#  ('던킨이나', 7),
#  ('김밥인', 41),
#  ('김밥이', 797),
#  ('부드러웠고', 486),
#  ('맛본', 1071),
#  ('맛났던', 143),
#  ('충암초', 1),
#  ('고등학교랑', 1),
#  ('가족단위', 290),
#  ('정성이', 1287),
#  ('1인분에', 911),
#  ('밝다는', 4),
#  ('보입니다', 702),
#  ('명지대에서', 2),
#  ('쓰신', 470),
#  ('저렴하면서', 97),
#  ('같긴', 1014),
#  ('운영되고', 156),
#  ('로스팅도', 91),
#  ('외부와', 33),
#  ('1층을', 58),
#  ('쏘쏘', 77),
#  ('되게', 5571),
#  ('조형물', 16),
#  ('뚝배기에', 387),
#  ('사이드로', 1541),
#  ('입맛인', 209),
#  ('여유', 1138),
#  ('수플레는', 115),
#  ('곳에서', 2682),
#  ('분위기입니다', 371),
#  ('떠오르기', 13),
#  ('판과', 21),
#  ('래미안', 14),
#  ('라테는', 1605),
#  ('곶감이', 8),
#  ('곱창집이', 75),
#  ('맵기는', 200),
#  ('동치미도', 87),
#  ('가게라', 287),
#  ('어디서', 991),
#  ('식으로', 878),
#  ('웃으며', 130),
#  ('이야기들도', 4),
#  ('생기', 28),
#  ('초월로', 2),
#  ('접근성', 295),
#  ('느낌입니다', 1105),
#  ('펑리수', 10),
#  ('좋으신', 235),
#  ('말씀해주셔서', 52),
#  ('초밥이고', 4),
#  ('먹을듯하네요', 11),
#  ('비싸', 411),
#  ('생각했으나', 119),
#  ('과열', 2),
#  ('자부심으로', 9),
#  ('체인점이어서', 8),
#  ('아파트', 488),
#  ('상가에', 234),
#  ('위치해서', 392),
#  ('특징은', 382),
#  ('관리도', 149),
#  ('멜로', 32),
#  ('케이크를', 1400),
#  ('준비하면', 6),
#  ('용기에', 119),
#  ('곰돌이', 63),
#  ('올려주셔서', 113),
#  ('선물하기', 74),
#  ('챙겨주셨는데', 16),
#  ('인정입니다', 101),
#  ('싸요', 168),
#  ('계신', 758),
#  ('들어있다', 725),
#  ('적게', 1110),
#  ('큰길로', 8),
#  ('길이고', 4),
#  ('2층까지', 309),
#  ('톤이라', 18),
#  ('풍미에', 63),
#  ('볼먹어본', 1),
#  ('넣은', 2959),
#  ('느낌이다', 2075),
#  ('메뉴판이', 351),
#  ('신메뉴도', 54),
#  ('불광천과', 3),
#  ('해물찜을', 39),
#  ('디너', 1629),
#  ('담아주시고', 46),
#  ('2900원입니다', 1),
#  ('비추입니다', 594),
#  ('힘들', 1465),
#  ('관련된', 108),
#  ('라테랑', 286),
#  ('의자가', 810),
#  ('불편할', 449),
#  ('신맛이', 938),
#  ('기었다', 1),
#  ('오는지', 95),
#  ('테이크아웃만', 261),
#  ('풍부하고', 497),
#  ('견과류랑', 47),
#  ('도미', 461),
#  ('쪽이', 465),
#  ('메밀을', 170),
#  ('주문할', 2052),
#  ('신선했거든요', 1),
#  ('먹어보려고', 161),
#  ('이에요', 195),
#  ('고추장', 1340),
#  ('1층이라', 24),
#  ('전문인', 61),
#  ('음료랑', 407),
#  ('팔지만', 95),
#  ('트고에', 1),
#  ('높아서', 1017),
#  ('4거리에', 2),
#  ('쉬우실', 13),
#  ('주인분이', 320),
#  ('빵들이', 730),
#  ('디저트류를', 65),
#  ('먹음직스러웠고', 5),
#  ('같이하는', 26),
#  ('잘라서', 648),
#  ('생겼는데', 409),
#  ('연유에', 17),
#  ('구비되어', 272),
#  ('북가좌', 1),
#  ('요리도', 833),
#  ('우육면이랑', 18),
#  ('새우튀김도', 303),
#  ('맥하기', 87),
#  ('스시집입니다', 46),
#  ('도로에', 124),
#  ('생선회를', 267),
#  ('미니롤들이', 1),
#  ('아담한', 885),
#  ('초밥집들을', 4),
#  ('시간만', 164),
#  ('생선초밥이', 9),
#  ('밤에는', 213),
#  ('야무네도', 1),
#  ('빡셈', 18),
#  ('나시고랭', 124),
#  ('결제는', 66),
#  ('없기에', 176),
#  ('밑반찬은', 681),
#  ('출구에서', 244),
#  ('위치하며', 31),
#  ('운영은', 22),
#  ('가천대나', 1),
#  ('김밥임', 11),
#  ('풀코스로', 39),
#  ('깔고', 255),
#  ('곱창은', 590),
#  ('받았는데도', 16),
#  ('바싹', 536),
#  ('월등히', 103),
#  ('1명이더라도', 1),
#  ('생각으로', 447),
#  ('공깃밥까지', 45),
#  ('조졌습니다', 7),
#  ('소금구이만', 17),
#  ('가능함', 343),
#  ('마비되는', 22),
#  ('홍차는', 112),
#  ('5자리', 7),
#  ('디저트류가', 199),
#  ('마들렌', 1021),
#  ('기억이', 4172),
#  ('수급을', 5),
#  ('가스를', 67),
#  ('특출난', 208),
#  ('창가라는', 2),
#  ('대자로', 71),
#  ('맛없었습니다', 60),
#  ('냄새나는', 168),
#  ('행주인지', 6),
#  ('상하더군요', 7),
#  ('그거', 1490),
#  ('괜찮았음', 1660),
#  ('주차했네요', 5),
#  ('포장했네요', 9),
#  ('담아주셔서', 86),
#  ('백반', 854),
#  ('고춧가루는', 43),
#  ('맞았습니다', 267),
#  ('겨자', 512),
#  ('육수만', 79),
#  ('직원분이', 2166),
#  ('전쟁터', 13),
#  ('왔더니', 223),
#  ('촬영하다니', 1),
#  ('이것도', 2073),
#  ('살아', 511),
#  ('어렵다', 575),
#  ('우리는', 1231),
#  ('상했는데도', 1),
#  ('현실이', 17),
#  ('물어도', 51),
#  ('대꾸조차', 3),
#  ('반죽도', 84),
#  ('떨어졌다', 141),
#  ('어이가', 528),
#  ('한마디라도', 17),
#  ('설탕이', 243),
#  ('여행', 4375),
#  ('친절하셨고요', 119),
#  ('가게의', 825),
#  ('성향', 48),
#  ('첨으로', 131),
#  ('닭볶음탕이', 203),
#  ('닭이네요', 3),
#  ('바싹하게', 34),
#  ('선풍기도', 16),
#  ('먹으려니', 122),
#  ('사용하셔서', 62),
#  ('까마귀가', 2),
#  ('가족이나', 101),
#  ('뜨거워요', 35),
#  ('장작을', 21),
#  ('개운한', 521),
#  ('무난히', 516),
#  ('청결', 718),
#  ('시간대였지만', 3),
#  ('000원에서', 20),
#  ('곰탕집이에요', 7),
#  ('깊었던', 332),
#  ('모습이에요', 9),
#  ('냉동이를', 2),
#  ('방문했었고', 26),
#  ('넘어갑니다', 104),
#  ('곰탕임', 1),
#  ('어려움은', 31),
#  ('체인점들과', 6),
#  ('배부른데도', 148),
#  ('특으로', 237),
#  ('그릇으로', 139),
#  ('사장님의', 1680),
#  ('칭찬합니다', 55),
#  ('메밀만', 20),
#  ('시골길', 30),
#  ('맞춤이다', 5),
#  ('찾은', 1563),
#  ('전병을', 37),
#  ('돌아가시는', 29),
#  ('메밀전', 210),
#  ('개의', 403),
#  ('챙겨주는', 78),
#  ('도착했을', 134),
#  ('훌륭하고', 812),
#  ('멀었다', 37),
#  ('고구마랑', 42),
#  ('토종닭이라', 40),
#  ('조절이', 296),
#  ('음식대비', 30),
#  ('일이', 2722),
#  ('경치는', 155),
#  ('공수와', 2),
#  ('솥뚜껑', 95),
#  ('경관이', 279),
#  ('솥뚜껑에', 75),
#  ('한차례', 37),
#  ('외부에서', 105),
#  ('부드러움에', 50),
#  ('백종원', 562),
#  ('갔다고', 108),
#  ('대체', 990),
#  ('티브이며', 1),
#  ('너무하다', 49),
#  ('코스로', 1552),
#  ('비주얼과', 393),
#  ('세련되었다', 7),
#  ('상당한데도', 2),
#  ('디저트에', 291),
#  ('3주차장에', 1),
#  ('식사하면', 96),
#  ('숯불닭갈비도', 15),
#  ('맛있었습니다만', 23),
#  ('거지', 1015),
#  ('나온다고', 400),
#  ('받았었는데요', 1),
#  ('성의', 469),
#  ('상차림이었어요', 3),
#  ('맛이고', 1577),
#  ('꾸며진', 235),
#  ('마음씨가', 10),
#  ('계셨고', 106),
#  ('남녀', 470),
#  ('찍고', 1270),
#  ('일은', 731),
#  ('봤다', 491),
#  ('거슬린다', 31),
#  ('앉아있기에', 20),
#  ('모르지만', 919),
#  ('고구마라테는', 17),
#  ('실내가', 462),
#  ('근사하다', 18),
#  ('포함된', 427),
#  ('부족함', 428),
#  ('소금만', 143),
#  ('적습니다', 287),
#  ('가깝고', 501),
#  ('비법', 136),
#  ('별미다', 267),
#  ('메밀전이', 76),
#  ('년은', 34),
#  ('전도', 765),
#  ('평일이라', 238),
#  ('적당함', 239),
#  ('앞뒤로', 62),
#  ('대면', 115),
#  ('넘어가요', 139),
#  ('한상차림', 124),
#  ('웰빙', 95),
#  ('음료수', 459),
#  ('2인분으로도', 2),
#  ('까먹음', 97),
#  ('달라는데도', 1),
#  ('그랬는지', 409),
#  ('쌈장은', 54),
#  ('남더라고요', 58),
#  ('했음', 869),
#  ('풍경도', 276),
#  ('연잎밥', 73),
#  ('쓴다고', 265),
#  ('소풍', 73),
#  ('단무지', 502),
#  ('김밥이라', 39),
#  ('특징이라', 39),
#  ('보길', 35),
#  ('빵이라고', 109),
#  ('바게트만', 54),
#  ('크림류는', 11),
#  ('달인이긴', 1),
#  ('크랜베리', 508),
#  ('리치한', 77),
#  ('숟가락도', 46),
#  ('같다는', 1116),
#  ('생수를', 41),
#  ('보들보들', 200),
#  ('애들만', 12),
#  ('메인인', 770),
#  ('시원함을', 67),
#  ('고집하시는', 8),
#  ('산책로가', 37),
#  ('엘레', 6),
#  ('금지인데', 7),
#  ('힐링할', 36),
#  ('가까워서', 885),
#  ('강쥐랑', 3),
#  ('레저를', 2),
#  ('기분전환하기', 31),
#  ('약밥은', 32),
#  ('사이로', 363),
#  ('기억함', 67),
#  ('생각했는데', 2334),
#  ('절로', 959),
#  ('겸하니', 2),
#  ('제공해도', 6),
#  ('아포가토를', 44),
#  ('편안함', 103),
#  ('식물이', 163),
#  ('한가운데에', 55),
#  ('지나칠', 279),
#  ('치즈케이크를', 208),
#  ('편이었으며', 15),
#  ('오른쪽에', 66),
#  ('꺼내놓고', 6),
#  ('꾸며', 122),
#  ('전망이지만', 2),
#  ('추천받고', 191),
#  ('가슴속까지', 6),
#  ('밖이고', 2),
#  ('드셔본', 47),
#  ('Mix', 6),
#  ('알갱이가', 164),
#  ('깍두기', 1345),
#  ('저녁을', 532),
#  ('브에', 4),
#  ('뷔페식당', 11),
#  ('다녀왔어요', 2108),
#  ('과자도', 147),
#  ('들었음', 709),
#  ('방문해봤습니다', 83),
#  ('한국어가', 28),
#  ('당분', 11),
#  ('누가', 1773),
#  ('닫는', 235),
#  ('고등어', 2075),
#  ('채소에', 75),
#  ('우렁이가', 18),
#  ('빵과', 1564),
#  ('가정식', 840),
#  ('불쾌한', 292),
#  ('부위는', 317),
#  ('주셨다고', 28),
#  ('룸으로', 482),
#  ('뺐었습니다', 1),
#  ('반찬들이', 672),
#  ('한국말', 125),
#  ('입식', 110),
#  ('농장', 54),
#  ('유명해질', 79),
#  ('오후를', 40),
#  ('전이던', 3),
#  ('대파를', 66),
#  ('본관', 168),
#  ('취소해달라고', 12),
#  ('알겠다고', 69),
#  ('팀이', 313),
#  ('취소해달라니깐', 1),
#  ('불친절의', 201),
#  ('믹스커피를', 5),
#  ('거지만', 395),
#  ('조명도', 315),
#  ('중턱에', 37),
#  ('서울로', 192),
#  ('해주시는데', 181),
#  ('다녀오려', 1),
#  ('지배하고', 11),
#  ('남매', 9),
#  ('편했던', 37),
#  ('방문하였는데', 184),
#  ('별반', 178),
#  ('관심을', 100),
#  ('2만', 2141),
#  ('원한다면', 535),
#  ('간장만', 80),
#  ('친절하시기까지', 37),
#  ('사용해서', 636),
#  ('가평에는', 1),
#  ('1인으로서', 31),
#  ('일요일', 1705),
#  ('해물파전은', 128),
#  ('부덕하다면서', 1),
#  ('해주는', 1002),
#  ('대고', 277),
#  ('갈빗집', 210),
#  ('살이라고', 12),
#  ('들러본', 136),
#  ...]

# %%
sorted_rdd = rdd.sortBy(lambda x: x[1], ascending=False)
sorted_rdd.take(30)
# Out:
# [('않고', 29799),
#  ('먹었는데', 25643),
#  ('고기', 25547),
#  ('양이', 25030),
#  ('먹으면', 22287),
#  ('음식', 22004),
#  ('분위기', 21628),
#  ('가격', 21597),
#  ('없는', 21428),
#  ('커피', 21315),
#  ('맛을', 20317),
#  ('카페', 20143),
#  ('메뉴', 19471),
#  ('처음', 19444),
#  ('살짝', 19399),
#  ('가게', 19371),
#  ('제일', 19202),
#  ('매우', 18777),
#  ('가서', 18627),
#  ('특히', 18623),
#  ('가장', 18262),
#  ('맛있었다', 18192),
#  ('저는', 17858),
#  ('가격이', 17830),
#  ('자주', 17599),
#  ('있어요', 17528),
#  ('생각보다', 17456),
#  ('추천', 17297),
#  ('많아서', 17127),
#  ('양도', 16931)]

# %%
import re
from itertools import islice

# 1) 불용어 로드 + broadcast (명사 불용어 중심으로)
with open("stopwords-ko.txt", encoding="utf-8") as f:
    stopwords = set(w.strip() for w in f if w.strip())
bc_stop = spark.sparkContext.broadcast(stopwords)

# 2) 파티션 단위로 Kiwi 1번만 초기화해서 명사/NNG/NNP만 추출
def extract_noun_bigrams_partition(rows):
    from kiwipiepy import Kiwi
    kiwi = Kiwi()  # ✅ 파티션당 1번
    stop = bc_stop.value

    for row in rows:
        text = row[0]
        if not text:
            continue

        # (선택) 너무 긴/이상한 문자 정리
        text = re.sub(r"\s+", " ", text).strip()

        tokens = []
        for tok in kiwi.tokenize(text):
            # Kiwi 품사 예: NNG(일반명사), NNP(고유명사)
            if tok.tag in ("NNG", "NNP"):
                w = tok.form
                if len(w) >= 2 and w not in stop:
                    tokens.append(w)

        # 명사 bigram 생성
        for a, b in zip(tokens, tokens[1:]):
            yield (f"{a} {b}", 1)

# 3) 실행 파이프라인
bigram_counts = (
    df.select("Review")
      .rdd
      .mapPartitions(extract_noun_bigrams_partition)
      .reduceByKey(lambda a, b: a + b)
      .filter(lambda kv: kv[0].split()[0] != kv[0].split()[1])
)

top_bigrams = bigram_counts.takeOrdered(50, key=lambda x: -x[1])
top_bigrams[:10]
# Out:
# Quantization is not supported for ArchType::Quantization is not supported for ArchType::Quantization is not supported for ArchType::Quantization is not supported for ArchType::Quantization is not supported for ArchType::neonneon. Fall back to non-quantized model.. Fall back to non-quantized model.neon
#
# Quantization is not supported for ArchType::. Fall back to non-quantized model.neonQuantization is not supported for ArchType::Quantization is not supported for ArchType::Quantization is not supported for ArchType::
# neon. Fall back to non-quantized model.. Fall back to non-quantized model.
#
# neonneon. Fall back to non-quantized model.. Fall back to non-quantized model.
#
# neonQuantization is not supported for ArchType::neon. Fall back to non-quantized model.
# neon. Fall back to non-quantized model.Quantization is not supported for ArchType::
# . Fall back to non-quantized model.neon
# . Fall back to non-quantized model.
# [('직원 친절', 14700),
#  ('가격 대비', 10120),
#  ('사장 친절', 8028),
#  ('방문 의사', 7897),
#  ('가락 국수', 7196),
#  ('평양 냉면', 6134),
#  ('무한 리필', 3737),
#  ('수제 버거', 3433),
#  ('크림 치즈', 3052),
#  ('치즈 케이크', 3035)]

# %%
for i in top_bigrams[:10]:
    print(i[0])

service = ["직원 친절", "사장 친절", "방문 의사"]
price = ["가격 대비", "무한 리필", "방문 의사"]
food = ["가락 국수", "수제 버거", "크림 치즈", "치즈 케이크"]

print({k: v for k, v in top_bigrams[:10]})
# Out:
# 직원 친절
# 가격 대비
# 사장 친절
# 방문 의사
# 가락 국수
# 평양 냉면
# 무한 리필
# 수제 버거
# 크림 치즈
# 치즈 케이크
# {'직원 친절': 14700, '가격 대비': 10120, '사장 친절': 8028, '방문 의사': 7897, '가락 국수': 7196, '평양 냉면': 6134, '무한 리필': 3737, '수제 버거': 3433, '크림 치즈': 3052, '치즈 케이크': 3035}

# %%
categories = {
    "service": set(service),
    "price": set(price),
    "food": set(food),
}

category_json = {k: {} for k in categories}

for phrase, count in top_bigrams:   # ← 슬라이스 제거 권장
    for cat, vocab in categories.items():
        if phrase in vocab:
            category_json[cat][phrase] = count
            
category_json
# Out:
# {'service': {'직원 친절': 14700, '사장 친절': 8028, '방문 의사': 7897},
#  'price': {'가격 대비': 10120, '방문 의사': 7897, '무한 리필': 3737},
#  'food': {'가락 국수': 7196, '수제 버거': 3433, '크림 치즈': 3052, '치즈 케이크': 3035}}

# %%
candidates = bigram_counts.takeOrdered(2000, key=lambda x: -x[1])

# %%
def is_noise(phrase):
    a, b = phrase.split()
    if len(a) < 2 or len(b) < 2:
        return True
    return False

candidates = [x for x in candidates if not is_noise(x[0])]

# %%
service_kw = ["친절", "서비스", "응대", "직원", "사장", "불친절"]
price_kw   = ["가격", "가성비", "대비", "리필", "무한", "할인", "쿠폰"]
food_kw    = ["국수", "냉면", "버거", "치즈", "케이크", "고기", "커피", "피자", "파스타"]

def classify(phrase):
    labels = []
    if any(k in phrase for k in service_kw): labels.append("service")
    if any(k in phrase for k in price_kw):   labels.append("price")
    if any(k in phrase for k in food_kw):    labels.append("food")
    if not labels: labels.append("other")
    return labels

# %%
category_json = {"service": {}, "price": {}, "food": {}, "other": {}}

for phrase, count in candidates:
    for lab in classify(phrase):
        category_json[lab][phrase] = count
category_json["service"]
# Out:
# {'직원 친절': 14700,
#  '사장 친절': 8028,
#  '친절 음식': 1932,
#  '친절 기분': 1910,
#  '서비스 친절': 1802,
#  '친절 서비스': 1502,
#  '분위기 서비스': 1236,
#  '사장 직원': 1078,
#  '친절 사장': 1042,
#  '직원 서비스': 1038,
#  '친절 직원': 1005,
#  '음식 서비스': 983,
#  '친절 방문': 979,
#  '가격 서비스': 946,
#  '친절 가격': 945,
#  '친절 분위기': 940,
#  '서비스 만족': 867,
#  '서비스 분위기': 857,
#  '분위기 친절': 805,
#  '분위기 직원': 776,
#  '친절 설명': 760,
#  '친절 고기': 741,
#  '종업원 친절': 735,
#  '서비스 음식': 729,
#  '아주머니 친절': 728,
#  '음식 직원': 707,
#  '서비스 최악': 655,
#  '서버 친절': 617,
#  '친절 가게': 608,
#  '주인 친절': 589,
#  '고기 직원': 572,
#  '가격 친절': 570,
#  '서비스 가격': 568,
#  '서빙 친절': 558,
#  '아르바이트 친절': 545,
#  '음식 친절': 533,
#  '이모 친절': 518,
#  '남자 직원': 509,
#  '셰프 친절': 508,
#  '직원 교육': 508,
#  '서비스 최고': 491,
#  '친절 응대': 486,
#  '친절 메뉴': 472,
#  '친절 만족': 471,
#  '사람 친절': 470,
#  '사람 직원': 457,
#  '서비스 기대': 452,
#  '친절 커피': 452,
#  '직원 고기': 419,
#  '주문 직원': 411,
#  '분위기 사장': 409,
#  '남자 사장': 407,
#  '사장 서비스': 405,
#  '직원 사장': 397,
#  '고기 서비스': 396,
#  '친절 사람': 390,
#  '친절 매장': 375,
#  '서비스 엉망': 363,
#  '친절 주문': 356,
#  '가게 사장': 356,
#  '추천 서비스': 352,
#  '친절 최고': 350,
#  '가격 직원': 350,
#  '서비스 마인드': 348,
#  '서비스 직원': 346,
#  '서비스 기분': 338,
#  '설명 친절': 338,
#  '직원 응대': 335,
#  '음식 사장': 329,
#  '친절 추천': 326,
#  '친절 주차': 326,
#  '서빙 직원': 325,
#  '서비스 청결': 323,
#  '사람 서비스': 322,
#  '친절 식사': 321,
#  '고기 친절': 320,
#  '알바 친절': 317,
#  '직원 주문': 315,
#  '사장 추천': 314,
#  '여자 직원': 314,
#  '사장 운영': 314,
#  '방문 사장': 308,
#  '카페 사장': 307,
#  '서비스 방문': 305,
#  '친절 반찬': 305,
#  '매장 직원': 305,
#  '방문 직원': 301,
#  '주문 사장': 298,
#  '가게 직원': 297,
#  '가격 사장': 296,
#  '서비스 고기': 288,
#  '방문 친절': 286,
#  '친절 식당': 286,
#  '친절 기대': 284,
#  '직원 태도': 283,
#  '친절 위생': 281,
#  '커피 직원': 273,
#  '친절 테이블': 269,
#  '여자 사장': 267,
#  '생각 직원': 260,
#  '아저씨 친절': 259,
#  '사장 음식': 255,
#  '주문 친절': 253,
#  '고기 사장': 251,
#  '친절 생각': 250,
#  '사장 부부': 247,
#  '서비스 제공': 247,
#  '웨이팅 직원': 242,
#  '위생 서비스': 239,
#  '생각 서비스': 239,
#  '친절 자리': 235,
#  '응대 친절': 234,
#  '친절 기본': 232,
#  '점원 친절': 232,
#  '깔끔 친절': 231,
#  '친절 웨이팅': 230,
#  '직원 마스크': 230,
#  '생각 사장': 229,
#  '서비스 생각': 229,
#  '친절 카페': 228,
#  '친절 구성비': 227,
#  '친절 음료': 227,
#  '친절 기억': 223,
#  '직원 음식': 221,
#  '자리 직원': 220,
#  '서비스 감사': 217,
#  '서비스 사장': 217,
#  '커피 사장': 216,
#  '서비스 정신': 216,
#  '서비스 개판': 216,
#  '사람 사장': 216,
#  '주문 서비스': 215,
#  '사장 말씀': 213,
#  '가게 친절': 212,
#  '친절 감사': 209,
#  '방문 서비스': 208,
#  '메뉴 직원': 207,
#  '직원 테이블': 207,
#  '생각 친절': 205,
#  '서비스 메뉴': 205,
#  '사장 가게': 205,
#  '최고 서비스': 203}

# %%
category_json["price"]
# Out:
# {'가격 대비': 10120,
#  '무한 리필': 3737,
#  '가격 생각': 2993,
#  '음식 가격': 1582,
#  '합리 가격': 1412,
#  '생각 가격': 1371,
#  '분위기 가격': 1347,
#  '메뉴 가격': 1340,
#  '가격 만족': 1209,
#  '가격 분위기': 1206,
#  '가격 합리': 1204,
#  '가격 부담': 1202,
#  '가격 음식': 1168,
#  '리필 가능': 1157,
#  '커피 가격': 1010,
#  '고기 가격': 952,
#  '가격 서비스': 946,
#  '친절 가격': 945,
#  '가격 퀄리티': 937,
#  '가격 구성비': 916,
#  '가격 사악': 896,
#  '가격 고기': 880,
#  '음료 가격': 820,
#  '주문 가격': 690,
#  '가격 방문': 686,
#  '대비 만족': 677,
#  '가격 메뉴': 649,
#  '부담 가격': 605,
#  '방문 가격': 586,
#  '가격 친절': 570,
#  '반찬 리필': 569,
#  '서비스 가격': 568,
#  '대비 가격': 510,
#  '파스타 가격': 488,
#  '만족 가격': 481,
#  '사람 가격': 472,
#  '가격 커피': 463,
#  '구성비 가격': 462,
#  '식당 가격': 458,
#  '추천 가격': 446,
#  '퀄리티 가격': 440,
#  '가격 사람': 417,
#  '최고 가격': 412,
#  '전체 가격': 409,
#  '카페 가격': 405,
#  '가격 추천': 403,
#  '기대 가격': 400,
#  '케이크 가격': 388,
#  '가격 구성': 379,
#  '가격 최고': 371,
#  '세트 가격': 366,
#  '가격 가게': 353,
#  '가격 직원': 350,
#  '요리 가격': 343,
#  '비교 가격': 338,
#  '가격 재료': 334,
#  '식사 가격': 330,
#  '버거 가격': 328,
#  '가격 식사': 322,
#  '구성 가격': 320,
#  '대비 음식': 316,
#  '가격 차이': 312,
#  '가격 반찬': 307,
#  '가격 기대': 306,
#  '웨이팅 가격': 299,
#  '돈가스 가격': 297,
#  '냉면 가격': 296,
#  '가격 사장': 296,
#  '전반 가격': 289,
#  '국물 가격': 286,
#  '재료 가격': 283,
#  '스테이크 가격': 282,
#  '대비 구성비': 281,
#  '가격 인상': 280,
#  '디저트 가격': 278,
#  '대비 퀄리티': 278,
#  '유명 가격': 276,
#  '코스 가격': 275,
#  '가격 파스타': 274,
#  '종류 가격': 272,
#  '가격 식당': 264,
#  '대비 생각': 261,
#  '처음 가격': 260,
#  '피자 가격': 257,
#  '가게 가격': 256,
#  '가격 음료': 250,
#  '맥주 가격': 250,
#  '초밥 가격': 245,
#  '만두 가격': 244,
#  '가격 웨이팅': 243,
#  '가격 서울': 237,
#  '와인 가격': 237,
#  '샐러드 가격': 237,
#  '가격 동네': 237,
#  '추가 가격': 233,
#  '크기 가격': 231,
#  '가격대 생각': 228,
#  '깔끔 가격': 228,
#  '대비 최고': 223,
#  '가격 기본': 222,
#  '대비 고기': 220,
#  '국수 가격': 220,
#  '다양 가격': 219,
#  '단점 가격': 218,
#  '가격 다양': 217,
#  '특별 가격': 217,
#  '가격 일반': 216,
#  '가격 근처': 215,
#  '인테리어 가격': 214,
#  '런치 가격': 212,
#  '가능 가격': 210,
#  '가격 주문': 209,
#  '정식 가격': 208,
#  '반찬 가격': 204,
#  '가격 카페': 204,
#  '가격 개인': 203,
#  '가격 고려': 203,
#  '안주 가격': 203}

# %%
category_json["food"]
# Out:
# {'가락 국수': 7196,
#  '평양 냉면': 6134,
#  '수제 버거': 3433,
#  '크림 치즈': 3052,
#  '치즈 케이크': 3035,
#  '크림 파스타': 2955,
#  '당근 케이크': 1632,
#  '오일 파스타': 1498,
#  '카페 커피': 1494,
#  '비빔 냉면': 1452,
#  '치즈 버거': 1451,
#  '리코타 치즈': 1418,
#  '화덕 피자': 1404,
#  '드립 커피': 1402,
#  '피자 파스타': 1398,
#  '로제 파스타': 1336,
#  '국물 고기': 1333,
#  '국수 국물': 1332,
#  '분위기 커피': 1315,
#  '고기 국물': 1309,
#  '고기 국수': 1253,
#  '고기 냄새': 1228,
#  '피자 도우': 1226,
#  '파스타 피자': 1168,
#  '치즈 돈가스': 1140,
#  '고기 만두': 1107,
#  '커피 디저트': 1098,
#  '커피 가격': 1010,
#  '비빔 막국수': 1003,
#  '고기 소스': 1001,
#  '오리 고기': 972,
#  '고기 가격': 952,
#  '냉면 육수': 916,
#  '칼국수 국물': 916,
#  '소스 고기': 899,
#  '크림 커피': 898,
#  '가격 고기': 880,
#  '커피 분위기': 874,
#  '고기 육즙': 865,
#  '치즈 샐러드': 838,
#  '국수 사리': 830,
#  '파운드 케이크': 809,
#  '고기 육수': 797,
#  '파스타 소스': 797,
#  '파스타 스테이크': 792,
#  '치즈 피자': 783,
#  '커피 카페': 776,
#  '고기 자체': 771,
#  '고기 양념': 770,
#  '아보카도 버거': 768,
#  '잔치 국수': 758,
#  '피자 치즈': 757,
#  '생각 고기': 757,
#  '커피 원두': 749,
#  '비엔나 커피': 746,
#  '크림 케이크': 742,
#  '친절 고기': 741,
#  '고기 튀김': 740,
#  '커피 크림': 737,
#  '고기 야채': 727,
#  '딸기 케이크': 720,
#  '커피 산미': 718,
#  '만두 고기': 674,
#  '커피 음료': 672,
#  '함흥 냉면': 664,
#  '양념 고기': 663,
#  '샐러드 파스타': 662,
#  '고기 식감': 661,
#  '고기 잡내': 653,
#  '파스타 주문': 644,
#  '고기 반찬': 642,
#  '칼국수 만두': 635,
#  '파스타 메뉴': 635,
#  '주문 고기': 630,
#  '버거 패티': 629,
#  '바지락 칼국수': 625,
#  '스테이크 파스타': 617,
#  '치즈 추가': 615,
#  '커피 케이크': 612,
#  '파스타 크림': 605,
#  '케이크 커피': 603,
#  '치즈 소스': 591,
#  '디저트 커피': 581,
#  '고기 생각': 577,
#  '고기 직원': 572,
#  '머리 고기': 570,
#  '돈가스 고기': 569,
#  '토마토 파스타': 568,
#  '커피 주문': 567,
#  '모차렐라 치즈': 566,
#  '야채 고기': 557,
#  '케이크 크림': 547,
#  '케이크 종류': 546,
#  '해물 칼국수': 544,
#  '커피 메뉴': 542,
#  '국수 고기': 539,
#  '초코 케이크': 538,
#  '고기 김치': 537,
#  '고기 추가': 536,
#  '케이크 주문': 530,
#  '냉면 평양': 529,
#  '치즈 크림': 514,
#  '커피 종류': 506,
#  '치즈 프라이': 504,
#  '소스 파스타': 504,
#  '고르곤졸라 피자': 502,
#  '냉면 만두': 498,
#  '수플레 팬케이크': 496,
#  '소스 치즈': 490,
#  '파스타 가격': 488,
#  '치킨 버거': 488,
#  '탕수육 고기': 472,
#  '트러플 파스타': 464,
#  '주문 커피': 463,
#  '가격 커피': 463,
#  '메뉴 고기': 462,
#  '파스타 리소토': 457,
#  '튀김 고기': 456,
#  '커피 사람': 453,
#  '친절 커피': 452,
#  '커피 라테': 451,
#  '커피 아메리카노': 450,
#  '산미 커피': 446,
#  '만두 칼국수': 445,
#  '베이컨 치즈': 445,
#  '라테 커피': 443,
#  '사람 커피': 442,
#  '돈가스 치즈': 442,
#  '생각 커피': 441,
#  '초계 국수': 433,
#  '육즙 고기': 427,
#  '커피 생각': 427,
#  '국수 면발': 425,
#  '파스타 생각': 424,
#  '블루 치즈': 424,
#  '고기 퀄리티': 423,
#  '처음 고기': 422,
#  '직원 고기': 419,
#  '스테이크 고기': 419,
#  '육수 고기': 418,
#  '멸치 국수': 414,
#  '들깨 칼국수': 407,
#  '조각 케이크': 406,
#  '커피 추천': 404,
#  '들기름 막국수': 402,
#  '파스타 샐러드': 402,
#  '인테리어 커피': 401,
#  '명란 파스타': 400,
#  '김치 고기': 399,
#  '고기 서비스': 396,
#  '버거 세트': 395,
#  '국물 칼국수': 392,
#  '봉골레 파스타': 392,
#  '갈비 고기': 392,
#  '피자 주문': 389,
#  '케이크 가격': 388,
#  '파스타 새우': 383,
#  '공간 커피': 379,
#  '칼국수 김치': 378,
#  '음료 케이크': 373,
#  '케이크 치즈': 372,
#  '커피 방문': 372,
#  '고기 밑반찬': 368,
#  '고기 사람': 367,
#  '케이크 딸기': 367,
#  '어란 파스타': 366,
#  '고기 최고': 360,
#  '새우 버거': 360,
#  '냉면 고기': 359,
#  '파스타 추천': 359,
#  '음료 커피': 355,
#  '커피 공간': 355,
#  '샐러드 피자': 355,
#  '소고기 쌀국수': 353,
#  '메뉴 치즈': 350,
#  '치즈 토마토': 349,
#  '메뉴 파스타': 347,
#  '반찬 고기': 347,
#  '고기 상태': 346,
#  '막국수 비빔': 345,
#  '버거 치즈': 345,
#  '식감 고기': 345,
#  '깔끔 고기': 343,
#  '더블 치즈': 343,
#  '피자 맥주': 341,
#  '무스 케이크': 340,
#  '고기 메뉴': 338,
#  '페퍼로니 피자': 338,
#  '사람 고기': 338,
#  '국수 주문': 333,
#  '치즈 타르트': 331,
#  '마르게리타 피자': 330,
#  '커피 베이커리': 330,
#  '더치 커피': 330,
#  '버거 가격': 328,
#  '레몬 케이크': 327,
#  '고깃집 고기': 327,
#  '김치 칼국수': 326,
#  '돼지 고기': 326,
#  '숯불 고기': 324,
#  '피자 생각': 324,
#  '방문 고기': 324,
#  '고기 처음': 322,
#  '고기 주문': 321,
#  '고기 친절': 320,
#  '고기 추천': 319,
#  '냄새 고기': 319,
#  '고기 만족': 315,
#  '원두 커피': 314,
#  '국물 국수': 314,
#  '커피 아이스': 308,
#  '고기 부위': 306,
#  '케이크 음료': 306,
#  '닭갈비 막국수': 306,
#  '분위기 고기': 305,
#  '파스타 방문': 304,
#  '치즈 감자': 302,
#  '고기 기름': 300,
#  '메밀 막국수': 299,
#  '피자 메뉴': 298,
#  '냉면 생각': 298,
#  '고기 종류': 298,
#  '고기 고명': 297,
#  '고기 볶음밥': 297,
#  '콜라 피자': 297,
#  '방문 커피': 297,
#  '냉면 가격': 296,
#  '메뉴 커피': 295,
#  '칼국수 사리': 293,
#  '파스타 토마토': 292,
#  '자리 커피': 291,
#  '냉면 처음': 291,
#  '국수 육수': 290,
#  '버거 수제': 290,
#  '식당 고기': 289,
#  '피자 샐러드': 289,
#  '파스타 오일': 288,
#  '파스타 트러플': 288,
#  '서비스 고기': 288,
#  '새우 파스타': 287,
#  '아메리카노 커피': 287,
#  '베트남 쌀국수': 285,
#  '고기 방문': 285,
#  '커피 기대': 285,
#  '국밥 고기': 283,
#  '추가 고기': 283,
#  '버거 주문': 282,
#  '커피 인테리어': 282,
#  '쌀국수 국물': 280,
#  '생각 치즈': 279,
#  '고기 냉면': 279,
#  '음식 고기': 278,
#  '막국수 메밀': 278,
#  '치즈 조합': 276,
#  '칠리 치즈': 276,
#  '기대 고기': 275,
#  '파스타 종류': 275,
#  '가격 파스타': 274,
#  '커피 직원': 273,
#  '커피 유명': 271,
#  '삼겹살 고기': 271,
#  '국수 가락': 271,
#  '페스토 파스타': 271,
#  '케이크 초코': 269,
#  '냉면 국물': 269,
#  '바게트 버거': 269,
#  '고기 치즈': 269,
#  '국수 그릇': 266,
#  '치즈 퐁듀': 266,
#  '파스타 기대': 266,
#  '그레이 케이크': 266,
#  '보쌈 고기': 265,
#  '커피 우유': 264,
#  '피자 추천': 263,
#  '체더 치즈': 260,
#  '추천 고기': 260,
#  '칼국수 볶음밥': 259,
#  '케이크 조각': 258,
#  '고기 두께': 258,
#  '냉면 그릇': 258,
#  '피자 가격': 257,
#  '국수 비빔국수': 256,
#  '토마토 치즈': 256,
#  '피자 조각': 256,
#  '최고 고기': 255,
#  '버거 생각': 255,
#  '진주 냉면': 255,
#  '파스타 처음': 254,
#  '고기 누린내': 254,
#  '소고기 돼지고기': 254,
#  '케이크 생각': 252,
#  '국수 추천': 252,
#  '고기 사장': 251,
#  '고기 순대': 251,
#  '종류 커피': 251,
#  '냉면 비빔': 251,
#  '부속 고기': 250,
#  '숙성 고기': 250,
#  '파스타 라자냐': 248,
#  '말이 국수': 248,
#  '쟁반 국수': 247,
#  '고기 삼겹살': 247,
#  '고기 새우': 246,
#  '버거 아보카도': 246,
#  '추천 커피': 246,
#  '파스타 분위기': 245,
#  '고기 된장찌개': 245,
#  '부라나 치즈': 245,
#  '치즈 풍미': 245,
#  '치즈 베이컨': 244,
#  '주문 치즈': 244,
#  '커피 최고': 244,
#  '국수 생각': 244,
#  '석쇠 불고기': 243,
#  '케이크 추천': 242,
#  '막국수 수육': 242,
#  '치즈 바게트': 242,
#  '커피 만족': 241,
#  '고기 돼지': 241,
#  '돼지 불고기': 240,
#  '고기 완자': 240,
#  '만두 냉면': 239,
#  '카페 케이크': 239,
#  '칼국수 주문': 238,
#  '패티 치즈': 238,
#  '고기 사이드': 238,
#  '고기 음식': 238,
#  '고기 채소': 237,
#  '피자 화덕': 237,
#  '메뉴 피자': 237,
#  '커피 가게': 236,
#  '케이크 당근': 234,
#  '치즈 볶음밥': 233,
#  '기름 고기': 233,
#  '주문 파스타': 233,
#  '동치미 국수': 233,
#  '리소토 파스타': 232,
#  '튀김옷 고기': 231,
#  '도우 치즈': 231,
#  '볶음밥 치즈': 229,
#  '케이크 시트': 228,
#  '치즈 생각': 227,
#  '우유 커피': 226,
#  '비빔 국수': 225,
#  '주문 피자': 224,
#  '만족 고기': 223,
#  '칼국수 바지락': 222,
#  '칼국수 해물': 222,
#  '파스타 치즈': 221,
#  '케이크 유명': 221,
#  '양고기 냄새': 220,
#  '대비 고기': 220,
#  '고기 기본': 220,
#  '한우 고기': 220,
#  '국수 가격': 220,
#  '치즈 샌드위치': 219,
#  '커피 사장': 216,
#  '디저트 케이크': 216,
#  '치즈 파스타': 215,
#  '고기 소금': 215,
#  '냉면 주문': 215,
#  '치즈 토핑': 214,
#  '개인 고기': 213,
#  '고기 육질': 213,
#  '케이크 카페': 213,
#  '고기 분위기': 213,
#  '아이스 커피': 212,
#  '커피 자체': 212,
#  '열무 국수': 212,
#  '생각 파스타': 211,
#  '나폴리 피자': 211,
#  '바스크 치즈': 211,
#  '고기 패티': 211,
#  '피자 토핑': 209,
#  '밑반찬 고기': 209,
#  '고기 짬뽕': 209,
#  '샐러드 치즈': 208,
#  '육수 냉면': 208,
#  '파스타 로제': 207,
#  '수육 고기': 207,
#  '치즈 고기': 207,
#  '칼국수 면발': 206,
#  '옥수수 피자': 206,
#  '케이크 디저트': 206,
#  '생각 피자': 206,
#  '칼국수 수제비': 206,
#  '냉면 사람': 205,
#  '도우 피자': 205,
#  '파스타 식감': 204,
#  '피자 종류': 204,
#  '고기 개인': 204,
#  '소고기 국수': 204,
#  '파스타 버섯': 204,
#  '분위기 파스타': 204,
#  '파스타 고기': 203}

# %%
category_json["other"]
# Out:
# {'방문 의사': 7897,
#  '남자 친구': 2866,
#  '새우 튀김': 2843,
#  '종류 다양': 2607,
#  '주차 공간': 2359,
#  '주문 메뉴': 2235,
#  '간장 게장': 2224,
#  '여자 친구': 2185,
#  '세트 메뉴': 2172,
#  '메뉴 주문': 2153,
#  '가게 분위기': 2149,
#  '분위기 음식': 2126,
#  '시그니처 메뉴': 2100,
#  '카페 분위기': 1991,
#  '대표 메뉴': 1949,
#  '플랫 화이트': 1865,
#  '메뉴 다양': 1845,
#  '브레이크 타임': 1834,
#  '테이블 간격': 1832,
#  '만족 식사': 1791,
#  '추가 주문': 1760,
#  '사이드 메뉴': 1742,
#  '취향 저격': 1724,
#  '토마토 소스': 1700,
#  '구성비 최고': 1691,
#  '주문 가능': 1690,
#  '코스 요리': 1689,
#  '추천 메뉴': 1661,
#  '방문 추천': 1652,
#  '생선 구이': 1649,
#  '마제 소바': 1640,
#  '주차 가능': 1607,
#  '가게 내부': 1527,
#  '크림 소스': 1521,
#  '망고 플레이트': 1516,
#  '평일 저녁': 1503,
#  '분위기 카페': 1490,
#  '주문 음식': 1463,
#  '사리 추가': 1463,
#  '육회 비빔밥': 1450,
#  '짬뽕 국물': 1435,
#  '메인 메뉴': 1412,
#  '순대 국밥': 1407,
#  '기대 실망': 1351,
#  '평일 점심': 1346,
#  '메뉴 구성': 1309,
#  '개인 취향': 1308,
#  '양념 갈비': 1245,
#  '저녁 방문': 1240,
#  '내부 인테리어': 1238,
#  '아이스 아메리카노': 1236,
#  '방문 예정': 1226,
#  '기대 생각': 1220,
#  '분위기 방문': 1176,
#  '국물 깔끔': 1175,
#  '친구 추천': 1169,
#  '방문 웨이팅': 1150,
#  '에그 타르트': 1145,
#  '음식 분위기': 1132,
#  '창가 자리': 1116,
#  '인테리어 분위기': 1114,
#  '매장 분위기': 1103,
#  '사람 웨이팅': 1101,
#  '새우 만두': 1097,
#  '강력 추천': 1091,
#  '생각 방문': 1084,
#  '돈가스 소스': 1080,
#  '저녁 웨이팅': 1075,
#  '핸드 드립': 1073,
#  '기분 식사': 1072,
#  '라면 사리': 1064,
#  '메뉴 추천': 1062,
#  '오랜만 방문': 1061,
#  '크림 새우': 1048,
#  '기본 충실': 1037,
#  '음식 생각': 1023,
#  '식사 메뉴': 1015,
#  '점심 방문': 1014,
#  '가족 외식': 1013,
#  '김치 만두': 1011,
#  '점심 식사': 1008,
#  '간장 소스': 990,
#  '사람 자리': 986,
#  '처음 방문': 984,
#  '추천 방문': 978,
#  '테이크 아웃': 970,
#  '예약 방문': 965,
#  '양념 게장': 963,
#  '저녁 식사': 960,
#  '바질 페스토': 947,
#  '가족 단위': 943,
#  '예약 필수': 941,
#  '바닐라 라테': 941,
#  '세트 주문': 941,
#  '지인 추천': 940,
#  '방문 사람': 930,
#  '위생 상태': 929,
#  '다양 메뉴': 929,
#  '사람 추천': 927,
#  '수제 맥주': 926,
#  '공영 주차장': 916,
#  '오징어 순대': 916,
#  '소금 구이': 914,
#  '기본 반찬': 910,
#  '햄버그 스테이크': 903,
#  '인기 메뉴': 895,
#  '식당 분위기': 894,
#  '근처 카페': 888,
#  '분위기 인테리어': 888,
#  '방문 메뉴': 880,
#  '주차장 주차': 872,
#  '점심 특선': 870,
#  '런치 세트': 870,
#  '짜장 짬뽕': 867,
#  '기대 이하': 864,
#  '방문 생각': 862,
#  '프렌치 토스트': 859,
#  '돼지 국밥': 854,
#  '주말 사람': 853,
#  '낙지 볶음': 852,
#  '연어 초밥': 849,
#  '계란 프라이': 848,
#  '메뉴 생각': 832,
#  '돈코쓰 라멘': 829,
#  '해물 파전': 829,
#  '가족 모임': 825,
#  '콩나물 국밥': 818,
#  '고등어 구이': 814,
#  '가게 이름': 808,
#  '점심 저녁': 807,
#  '메뉴 방문': 806,
#  '기대 방문': 805,
#  '근처 방문': 803,
#  '재료 소진': 800,
#  '자리 불편': 798,
#  '카페 내부': 790,
#  '생활 달인': 786,
#  '선택 가능': 782,
#  '순두부 찌개': 779,
#  '음식 깔끔': 776,
#  '메뉴 선택': 775,
#  '사람 음식': 775,
#  '점심 웨이팅': 774,
#  '연어 덮밥': 771,
#  '짬뽕 탕수육': 766,
#  '내부 분위기': 766,
#  '위치 카페': 766,
#  '점심 메뉴': 764,
#  '음료 디저트': 760,
#  '오픈 키친': 755,
#  '돼지 냄새': 754,
#  '식사 가능': 753,
#  '이름 기억': 746,
#  '친구 방문': 745,
#  '맥주 안주': 735,
#  '편안 분위기': 735,
#  '포장 가능': 734,
#  '동네 주민': 733,
#  '생각 음식': 728,
#  '다양 종류': 722,
#  '음식 만족': 721,
#  '점심 사람': 718,
#  '전화 예약': 714,
#  '김치 볶음밥': 708,
#  '간장 새우': 706,
#  '구성비 생각': 706,
#  '찹쌀 탕수육': 705,
#  '카페 인테리어': 703,
#  '브런치 메뉴': 701,
#  '참치 김밥': 694,
#  '주말 저녁': 690,
#  '자리 안내': 690,
#  '생각 사람': 689,
#  '주말 웨이팅': 685,
#  '브런치 카페': 682,
#  '카페 거리': 680,
#  '음식 주문': 677,
#  '메뉴 설명': 677,
#  '분위기 최고': 677,
#  '디저트 카페': 676,
#  '태국 음식': 676,
#  '만족 방문': 673,
#  '장어 덮밥': 672,
#  '가족 식사': 672,
#  '처음 생각': 670,
#  '음식 전체': 670,
#  '테이블 자리': 669,
#  '미디엄 레어': 667,
#  '트러플 오일': 667,
#  '데이트 코스': 662,
#  '갈치 구이': 661,
#  '베스트 메뉴': 661,
#  '인도 카레': 658,
#  '골목 위치': 657,
#  '플레 히팅': 656,
#  '데이트 장소': 654,
#  '숯불 닭갈비': 653,
#  '분위기 데이트': 648,
#  '저녁 사람': 648,
#  '런치 코스': 646,
#  '카페 음료': 645,
#  '식사 방문': 642,
#  '부산 여행': 641,
#  '동네 카페': 641,
#  '김치 깍두기': 639,
#  '음식 퀄리티': 634,
#  '방문 만족': 633,
#  '분위기 사람': 632,
#  '크림 리소토': 630,
#  '근처 위치': 626,
#  '사람 분위기': 624,
#  '음식 방문': 622,
#  '가지 튀김': 622,
#  '전체 음식': 621,
#  '딸기 크림': 621,
#  '전체 분위기': 620,
#  '생각 메뉴': 620,
#  '탄두 치킨': 619,
#  '평일 사람': 619,
#  '사람 생각': 619,
#  '한옥 마을': 618,
#  '탕수육 소스': 617,
#  '오징어 튀김': 615,
#  '치킨 카레': 613,
#  '꼬막 비빔밥': 610,
#  '한국인 입맛': 608,
#  '자리 테이블': 606,
#  '음식 전반': 605,
#  '조개 구이': 601,
#  '사람 방문': 601,
#  '메인 요리': 599,
#  '음식 사람': 598,
#  '이탈리안 레스토랑': 597,
#  '전체 만족': 597,
#  '즉석 떡볶이': 596,
#  '예약 가능': 595,
#  '등심 안심': 594,
#  '베이커리 카페': 593,
#  '유명 이유': 591,
#  '올리브 오일': 589,
#  '안심 등심': 586,
#  '자리 사람': 586,
#  '무료 주차': 585,
#  '중국 음식': 583,
#  '사람 대기': 583,
#  '주말 점심': 581,
#  '의자 불편': 578,
#  '내부 테이블': 577,
#  '짬뽕 순두부': 576,
#  '짜장면 짬뽕': 574,
#  '일본 라멘': 573,
#  '메밀 전병': 569,
#  '분위기 고급': 569,
#  '가게 사람': 566,
#  '분위기 식사': 566,
#  '고급 분위기': 564,
#  '만두 김치': 561,
#  '적극 추천': 560,
#  '단일 메뉴': 560,
#  '파인 다이닝': 559,
#  '식당 내부': 553,
#  '주문 생각': 553,
#  '떡볶이 튀김': 551,
#  '우럭 조림': 548,
#  '마플 평점': 548,
#  '삼겹살 목살': 547,
#  '맥주 종류': 547,
#  '라멘 국물': 547,
#  '구성비 분위기': 543,
#  '떡볶이 국물': 542,
#  '튀김 새우': 541,
#  '분위기 만족': 541,
#  '야외 테라스': 540,
#  '동치미 국물': 538,
#  '기본 메뉴': 538,
#  '망고 하이': 534,
#  '유명 카페': 534,
#  '전반 만족': 534,
#  '돼지 갈비': 534,
#  '포장 주문': 533,
#  '개인 생각': 530,
#  '주차 불편': 530,
#  '마늘 바게트': 528,
#  '주차장 이용': 527,
#  '선지 해장국': 527,
#  '웨이팅 생각': 527,
#  '오픈 주방': 527,
#  '평일 웨이팅': 525,
#  '가게 테이블': 525,
#  '음식 메뉴': 525,
#  '회사 근처': 524,
#  '카페 방문': 524,
#  '음식 추천': 518,
#  '사람 입맛': 518,
#  '크림 라테': 518,
#  '웨이팅 사람': 518,
#  '방문 가게': 517,
#  '프렌치 프라이': 516,
#  '가게 인테리어': 516,
#  '갈비 양념': 515,
#  '방문 음식': 515,
#  '오픈 웨이팅': 515,
#  '유명 방문': 514,
#  '메뉴 이름': 514,
#  '예상 가능': 513,
#  '유명 사람': 513,
#  '조절 가능': 512,
#  '맛집 인정': 511,
#  '재료 본연': 511,
#  '처음 사람': 511,
#  '유니 짜장': 511,
#  '반숙 계란': 509,
#  '식당 음식': 509,
#  '카페 사람': 508,
#  '생각 분위기': 507,
#  '테라스 자리': 507,
#  '아침 식사': 506,
#  '방문 분위기': 505,
#  '사람 주문': 505,
#  '음료 주문': 504,
#  '샐러드 소스': 502,
#  '국물 떡볶이': 502,
#  '간장 양념': 500,
#  '생각 가게': 500,
#  '아이스 라테': 499,
#  '국물 김치': 499,
#  '음식 설명': 498,
#  '짜장 소스': 495,
#  '우유 크림': 494,
#  '지역 주민': 494,
#  '모임 장소': 493,
#  '마플 리뷰': 493,
#  '탕수육 짬뽕': 493,
#  '장어 구이': 492,
#  '만두 군만두': 491,
#  '음식 처음': 491,
#  '동네 빵집': 491,
#  '방문 카페': 490,
#  '계란 노른자': 489,
#  '튀김 소스': 488,
#  '정식 주문': 488,
#  '깔끔 국물': 486,
#  '마지막 볶음밥': 486,
#  '식당 방문': 484,
#  '음식 자체': 484,
#  '칠리 새우': 484,
#  '사람 테이블': 484,
#  '특수 부위': 483,
#  '바닐라 아이스크림': 483,
#  '소주 한잔': 483,
#  '분위기 추천': 482,
#  '디저트 종류': 480,
#  '분위기 생각': 478,
#  '방문 식당': 478,
#  '주차 가게': 478,
#  '예약 자리': 477,
#  '동네 사람': 476,
#  '최근 방문': 476,
#  '등심 돈가스': 475,
#  '사람 이유': 475,
#  '세트 구성': 474,
#  '분위기 구성비': 473,
#  '버섯 크림': 473,
#  '해물 라면': 472,
#  '만두 새우': 472,
#  '일본 가정식': 471,
#  '유명 식당': 471,
#  '평일 오후': 467,
#  '분위기 메뉴': 466,
#  '식당 생각': 466,
#  '음식 기대': 466,
#  '국물 일품': 465,
#  '음식 사진': 465,
#  '메뉴 음식': 465,
#  '기대 만족': 464,
#  '카페 공간': 461,
#  '테이블 의자': 461,
#  '분위기 테이블': 461,
#  '에그 베네딕트': 458,
#  '오징어 먹물': 458,
#  '야외 테이블': 457,
#  '처음 음식': 457,
#  '생각 만족': 456,
#  '들깨 가루': 456,
#  '재료 사용': 456,
#  '유명 기대': 455,
#  '웨이팅 기본': 455,
#  '가락 국숫집': 455,
#  '해물 짬뽕': 454,
#  '웨이팅 방문': 453,
#  '인테리어 음식': 452,
#  '감성 카페': 450,
#  '메뉴 추가': 449,
#  '주문 추천': 448,
#  '가게 웨이팅': 447,
#  '동네 식당': 446,
#  '짬뽕 짜장': 446,
#  '화이트 와인': 446,
#  '연어 샐러드': 445,
#  '사람 가게': 444,
#  '주인 아주머니': 444,
#  '기본 안주': 443,
#  '매장 테이블': 442,
#  '예약 추천': 441,
#  '자리 예약': 440,
#  '평일 방문': 439,
#  '음식 종류': 438,
#  '초밥 연어': 438,
#  '방문 기대': 438,
#  '하루 종일': 438,
#  '사골 육수': 438,
#  '딸기 라테': 437,
#  '분위기 음료': 436,
#  '새우 크림': 436,
#  '테이블 회전': 435,
#  '사골 국물': 435,
#  '레드 와인': 434,
#  '간장 베이스': 433,
#  '생각 국물': 431,
#  '국물 생각': 431,
#  '토핑 추가': 431,
#  '방문 주문': 431,
#  '카페 생각': 430,
#  '새우 볶음밥': 430,
#  '런치 메뉴': 430,
#  '백종원 천왕': 430,
#  '유명 메뉴': 430,
#  '생각 기대': 429,
#  '가게 주차': 429,
#  '매장 내부': 428,
#  '테이블 사람': 427,
#  '주문 자리': 427,
#  '웨이팅 자리': 427,
#  '방문 예약': 425,
#  '태국 음식점': 425,
#  '가게 생각': 424,
#  '반찬 김치': 423,
#  '카페 추천': 422,
#  '공간 테이블': 421,
#  '오후 방문': 421,
#  '반찬 셀프': 421,
#  '가족 방문': 420,
#  '회식 장소': 420,
#  '친구 만족': 420,
#  '한옥 카페': 419,
#  '마늘 소스': 418,
#  '메뉴 만족': 417,
#  '웨이팅 음식': 417,
#  '초등학생 입맛': 417,
#  '멍게 비빔밥': 417,
#  '만두 주문': 417,
#  '주문 테이블': 416,
#  '카페 자리': 412,
#  '구경 재미': 411,
#  '사람 메뉴': 411,
#  '모둠 순대': 411,
#  '유명 웨이팅': 409,
#  '음식 기분': 408,
#  '중국 요리': 408,
#  '분위기 가게': 407,
#  '만두 육즙': 406,
#  '메뉴 도전': 405,
#  '자리 웨이팅': 405,
#  '숯불 구이': 405,
#  '디너 코스': 405,
#  '스테이크 샐러드': 405,
#  '스시 오마카세': 405,
#  '최고 생각': 404,
#  '단호박 수프': 404,
#  '자몽 이드': 403,
#  '소스 조화': 403,
#  '보리 굴비': 403,
#  '공깃밥 추가': 403,
#  '주문 음료': 403,
#  '안심 스테이크': 402,
#  '안심 돈가스': 402,
#  '주문 기본': 401,
#  '도착 웨이팅': 401,
#  '웨이팅 필수': 401,
#  '네이버 예약': 400,
#  '라테 주문': 400,
#  '분위기 식당': 399,
#  '공간 분위기': 399,
#  '생각 구성비': 398,
#  '오픈 도착': 398,
#  '게장 양념': 397,
#  '튀김 만두': 396,
#  '금요일 저녁': 394,
#  '애견 동반': 392,
#  '볶음밥 주문': 392,
#  '생각 개인': 392,
#  '목살 삼겹살': 392,
#  '테이블 음식': 391,
#  '코스 구성': 390,
#  '기분 음식': 390,
#  '구성비 방문': 390,
#  '전복 내장': 390,
#  '카페 디저트': 389,
#  '기사 식당': 388,
#  '성게 비빔밥': 387,
#  '시금치 카레': 387,
#  '동네 중국집': 387,
#  '육수 국물': 387,
#  '메뉴 기대': 385,
#  '자리 주문': 385,
#  '추가 가능': 384,
#  '방문 대기': 384,
#  '음식 재료': 383,
#  '인스타 감성': 383,
#  '호텔 뷔페': 382,
#  '푸드 코트': 382,
#  '외관 내부': 382,
#  '주문 사람': 382,
#  '방문 처음': 381,
#  '초코 크루아': 381,
#  '아메리카노 산미': 381,
#  '전반 음식': 381,
#  '아바이 순대': 381,
#  '차슈 추가': 380,
#  '생각 주문': 380,
#  '소스 생각': 380,
#  '웨이팅 가게': 380,
#  '국밥 국물': 380,
#  '식사 추천': 379,
#  '쟁반 짜장': 378,
#  '말차 라테': 378,
#  '근처 식당': 378,
#  '멸치 육수': 377,
#  '커플 세트': 377,
#  '스타 필드': 377,
#  '크림 브륄레': 377,
#  '생선 가스': 377,
#  '제주 여행': 375,
#  '식사 웨이팅': 374,
#  '시즌 메뉴': 374,
#  '코스 메뉴': 373,
#  '식감 소스': 373,
#  '소스 조합': 373,
#  '개인 입맛': 372,
#  '메뉴 기본': 371,
#  '지하 위치': 371,
#  '음식 속도': 371,
#  '반찬 가짓수': 370,
#  '버터 프레첼': 369,
#  '베트남 음식': 369,
#  '재료 조화': 368,
#  '테이블 불편': 368,
#  '다양 음식': 368,
#  '평일 런치': 368,
#  '크림 딸기': 366,
#  '특유 냄새': 366,
#  '분위기 마음': 364,
#  '생각 추천': 364,
#  '다이닝 코드': 363,
#  '커스터드 크림': 362,
#  '국물 면발': 361,
#  '자리 음식': 361,
#  '참치 뱃살': 361,
#  '사람 카페': 361,
#  '오픈 사람': 361,
#  '메뉴 구성비': 360,
#  '정육 식당': 360,
#  '웨이팅 회전': 360,
#  '특제 소스': 359,
#  '기본 제공': 359,
#  '내추럴 와인': 359,
#  '꼬막 무침': 358,
#  '유명 빵집': 356,
#  '방문 자리': 356,
#  '소스 튀김': 355,
#  '요즘 날씨': 355,
#  '디저트 음료': 354,
#  '테이블 주문': 354,
#  '녹차 아이스크림': 354,
#  '주꾸미 볶음': 353,
#  '망고 빙수': 353,
#  '골목 식당': 352,
#  '샐러드 드레싱': 352,
#  '모둠 초밥': 352,
#  '주인 아저씨': 352,
#  '오징어 볶음': 352,
#  '하우스 와인': 352,
#  '매장 사람': 352,
#  '코로나 시국': 352,
#  '패티 육즙': 351,
#  '동반 가능': 351,
#  '주말 방문': 351,
#  '코스 주문': 351,
#  '양념 구이': 350,
#  '요즘 유행': 350,
#  '군만두 만두': 350,
#  '가게 자리': 350,
#  '장소 추천': 349,
#  '디저트 메뉴': 349,
#  '식사 음식': 349,
#  '이용 가능': 348,
#  '땅콩 소스': 348,
#  '짜장 탕수육': 348,
#  '처음 국물': 347,
#  '음식 서빙': 347,
#  '위치 분위기': 346,
#  '배달 주문': 346,
#  '토요일 저녁': 346,
#  '위생 신경': 346,
#  '소스 돈가스': 345,
#  '오픈 방문': 345,
#  '국물 만두': 345,
#  '야외 자리': 344,
#  '점심시간 사람': 344,
#  '주변 사람': 344,
#  '요리 전문점': 344,
#  '카레 가락': 343,
#  '추가 메뉴': 342,
#  '순두부 젤라또': 342,
#  '와인 리스트': 342,
#  '테이 스팅': 342,
#  '제주 돼지': 341,
#  '곱창 전골': 340,
#  '주차 자리': 340,
#  '처음 주문': 340,
#  '계란 볶음밥': 340,
#  '생각 웨이팅': 339,
#  '메뉴 종류': 339,
#  '고구마 튀김': 338,
#  '부추 무침': 338,
#  '반찬 깔끔': 338,
#  '카이 선동': 338,
#  '기억 방문': 337,
#  '자리 분위기': 337,
#  '추가 추천': 336,
#  '국물 최고': 336,
#  '면발 국물': 336,
#  '국물 자극': 336,
#  '미슐랭 스타': 336,
#  '먹물 리소토': 334,
#  '양파 절임': 334,
#  '조합 최고': 334,
#  '드라이 에이징': 334,
#  '돈가스 카레': 333,
#  '점심시간 웨이팅': 333,
#  '아인슈페너 크림': 333,
#  '주차 무료': 333,
#  '공간 사람': 333,
#  '김치 말이': 332,
#  '고등어 초밥': 332,
#  '새우 식감': 332,
#  '분위기 깡패': 332,
#  '식당 메뉴': 332,
#  '음식 식당': 331,
#  '음식 와인': 330,
#  '런치 방문': 330,
#  '처음 메뉴': 330,
#  '음악 소리': 330,
#  '곰탕 국물': 330,
#  '필수 코스': 329,
#  '다운 다우너': 329,
#  '건강 음식': 329,
#  '어묵 국물': 328,
#  '위치 식당': 327,
#  '등심 스테이크': 327,
#  '인테리어 카페': 326,
#  '내부 공간': 326,
#  '전화 주문': 326,
#  '웨이팅 주문': 326,
#  '식당 사람': 325,
#  '분위기 맥주': 325,
#  '바닐라 크림': 325,
#  '메뉴 고민': 325,
#  '음식 최고': 324,
#  '계란 추가': 324,
#  '가게 음식': 324,
#  '음식 정성': 324,
#  '두부 전골': 324,
#  '음식 가게': 323,
#  '과일 주스': 323,
#  '명란 크림': 322,
#  '야외 좌석': 321,
#  '식사 자리': 321,
#  '바질 토마토': 321,
#  '소주 안주': 321,
#  '시저 샐러드': 321,
#  '유일 단점': 321,
#  '웨이팅 입장': 321,
#  '분위기 공간': 321,
#  '두부 김치': 320,
#  '생각 실망': 320,
#  '튀김 떡볶이': 320,
#  '춘천 닭갈비': 319,
#  '소스 새우': 319,
#  '튀김 기름': 319,
#  '음식 구성비': 319,
#  '스테이크 미디엄': 319,
#  '포카 치아': 319,
#  '국밥 순대': 318,
#  '식사 분위기': 318,
#  '방문 리뷰': 318,
#  '분위기 자리': 317,
#  '감자 샐러드': 317,
#  '원두 선택': 315,
#  '카드 결제': 315,
#  '해물 뚝배기': 315,
#  '회전 초밥': 314,
#  '녹차 라테': 314,
#  '국물 육수': 314,
#  '기름 냄새': 313,
#  '우유 얼음': 312,
#  '일요일 저녁': 312,
#  '떡볶이 소스': 311,
#  '국물 해장': 311,
#  '메밀 함량': 311,
#  '사워 크림': 310,
#  '주택 개조': 310,
#  '시트 포테이토': 310,
#  '차돌 짬뽕': 309,
#  '웨이팅 테이블': 309,
#  '평점 기대': 309,
#  '카페 메뉴': 309,
#  '인테리어 고급': 309,
#  '카레 돈가스': 309,
#  '양념 소스': 309,
#  '짬뽕 해물': 309,
#  '깍두기 볶음밥': 309,
#  '만족 메뉴': 308,
#  '순댓국 순대': 308,
#  '요리 메뉴': 308,
#  '블루 리본': 307,
#  '버터 풍미': 307,
#  '가게 방문': 307,
#  '구성비 식당': 307,
#  '키오스크 주문': 306,
#  '버터 크림': 306,
#  '아메리카노 주문': 306,
#  '주문 처음': 306,
#  '국물 감칠맛': 305,
#  '현금 결제': 305,
#  '옥돔 구이': 305,
#  '게장 간장': 304,
#  '김치 국물': 304,
#  '사람 만족': 304,
#  '채끝 등심': 304,
#  '음료 종류': 304,
#  '숙성 스시': 303,
#  '생각 카페': 303,
#  '기분 방문': 303,
#  '분위기 음악': 303,
#  '계절 메뉴': 303,
#  '메뉴 분위기': 303,
#  '그릭 요구르트': 303,
#  '친구 생일': 302,
#  '방문 평일': 302,
#  '크림 카레': 302,
#  '기분 전환': 302,
#  '로제 소스': 301,
#  '여행 기분': 301,
#  '메뉴 크림': 301,
#  '사람 예약': 301,
#  '생각 테이블': 301,
#  '양념 자극': 301,
#  '예약 전화': 300,
#  '방문 테이블': 300,
#  '주문 국물': 300,
#  '양배추 샐러드': 300,
#  '음료 메뉴': 300,
#  '와인 페어': 299,
#  '새우 소스': 299,
#  '거리 위치': 298,
#  '좌식 테이블': 298,
#  '의자 테이블': 298,
#  '주문 추가': 298,
#  '생각 자리': 298,
#  '중요 생각': 297,
#  '카페 라테': 297,
#  '식사 사람': 297,
#  '크림 모카': 297,
#  '소스 샐러드': 297,
#  '기대 음식': 297,
#  '초코 크림': 296,
#  '베트남 음식점': 296,
#  '누룽지 백숙': 296,
#  '소프트 크랩': 296,
#  '아보카도 샐러드': 296,
#  '평일 주말': 296,
#  '만족 음식': 296,
#  '기대 메뉴': 296,
#  '아뮤즈 부시': 296,
#  '스테이크 하우스': 296,
#  '런치 디너': 295,
#  '곱창 대창': 293,
#  '한정 메뉴': 293,
#  '소유 라멘': 293,
#  '사람 식사': 293,
#  '메뉴 새우': 293,
#  '주문 동시': 293,
#  '리뷰 방문': 293,
#  '아메리카노 라테': 293,
#  '사람 평일': 293,
#  '해시 브라운': 292,
#  '오픈 샌드위치': 292,
#  '여행 방문': 292,
#  '돈가스 생각': 292,
#  '야채 곱창': 291,
#  '피크 타임': 291,
#  '소스 야채': 290,
#  '무료 제공': 290,
#  '소스 추가': 290,
#  '매장 인테리어': 290,
#  '메뉴 사진': 289,
#  '사람 주말': 288,
#  '방문 식사': 288,
#  '음식 자극': 288,
#  '오리 백숙': 287,
#  '사람 식당': 287,
#  '버터 치킨': 287,
#  '애플 망고': 287,
#  '토마토 베이스': 287,
#  '양념 간장': 287,
#  '내부 자리': 286,
#  '육수 베이스': 286,
#  '분위기 와인': 286,
#  '추천 음식': 286,
#  '한국 사람': 286,
#  '친구 모임': 286,
#  '대창 덮밥': 285,
#  '사진 카페': 285,
#  '테이블 웨이팅': 285,
#  '제주도 여행': 284,
#  '생각 처음': 284,
#  '분위기 사진': 284,
#  '크림 조화': 284,
#  '저녁 대기': 283,
#  '버터 갈릭': 283,
#  '음식 기본': 283,
#  '구이 양념': 283,
#  '겨자 소스': 282,
#  '웨이팅 평일': 280,
#  '프렌치 레스토랑': 280,
#  '웨이팅 감수': 279,
#  '개조 카페': 279,
#  '주변 카페': 279,
#  '목살 스테이크': 278,
#  '버그 스테이크': 278,
#  '구성비 음식': 278,
#  '나가사키 짬뽕': 278,
#  '주차 근처': 278,
#  '방문 당시': 278,
#  '실내 분위기': 278,
#  '근처 추천': 278,
#  '게살 볶음밥': 277,
#  '경양식 돈가스': 277,
#  '스테이크 소스': 277,
#  '고추 튀김': 277,
#  '소스 토마토': 276,
#  '다시마 식초': 276,
#  '분위기 편안': 276,
#  '튀김 가락': 276,
#  '특유 식감': 276,
#  '바질 라멘': 276,
#  '위치 주차': 275,
#  '도착 대기': 275,
#  '식사 기분': 275,
#  '생각 소스': 275,
#  '순대 순댓국': 275,
#  '샐러드 주문': 274,
#  '레스토랑 분위기': 274,
#  '고사리 육개장': 274,
#  '메뉴 개인': 274,
#  '식사 만족': 274,
#  '분위기 친구': 273,
#  '사람 이해': 273,
#  '외국인 친구': 273,
#  '짬뽕 짜장면': 272,
#  '딸기 우유': 272,
#  '마음 방문': 272,
#  '개인 카페': 272,
#  '다양 재료': 272,
#  '분위기 디저트': 272,
#  '가게 자체': 271,
#  '자극 음식': 271,
#  '음식 반찬': 271,
#  '요리 음식': 271,
#  '라멘 차슈': 271,
#  '바게트 샌드위치': 271,
#  '음식 테이블': 270,
#  '화이트 초콜릿': 270,
#  '와인 음식': 270,
#  '튀김 주문': 270,
#  '사람 유명': 270,
#  '디저트 가게': 269,
#  '웨이팅 오픈': 269,
#  '식초 겨자': 269,
#  '고추 짜장': 269,
#  '좌석 불편': 268,
#  '야채 소스': 268,
#  '방문 실망': 268,
#  '건물 위치': 268,
#  '일요일 휴무': 268,
#  '친구 분위기': 268,
#  '설명 필요': 268,
#  '스테이크 덮밥': 267,
#  '바나나 푸딩': 267,
#  '식사 대용': 266,
#  '런치 오마카세': 266,
#  '떡볶이 양념': 266,
#  '분위기 기분': 265,
#  '육즙 만두': 265,
#  '시장 위치': 265,
#  '버터 스콘': 265,
#  '돼지 껍질': 265,
#  '개선 필요': 265,
#  '환상 조합': 264,
#  '동네 유명': 264,
#  '웨이팅 메뉴': 263,
#  '들깨 수제비': 263,
#  '맥주 주문': 263,
#  '사람 주차': 263,
#  '만두 만두피': 263,
#  '소스 자극': 263,
#  '위치 가게': 262,
#  '딸기 타르트': 262,
#  '저녁 시간대': 262,
#  '요리 생각': 262,
#  '세트 구성비': 262,
#  '가게 위치': 262,
#  '사람 정신': 262,
#  '곱창 막창': 262,
#  '요리 주문': 261,
#  '덮밥 연어': 261,
#  '소스 특이': 261,
#  '메뉴 식사': 261,
#  '소스 소금': 261,
#  '성인 남성': 261,
#  '황태 구이': 260,
#  '구이 주문': 260,
#  '탕수육 튀김': 260,
#  '가정집 개조': 260,
#  '북경 오리': 260,
#  '소머리 국밥': 260,
#  '웨이팅 가치': 259,
#  '유명 가게': 259,
#  '가야 이유': 259,
#  '피시 소스': 259,
#  '여유 식사': 258,
#  '카레 치킨': 258,
#  '비빔밥 육회': 258,
#  '예전 방문': 258,
#  '식당 추천': 257,
#  '보쌈 정식': 257,
#  '만두 생각': 257,
#  '코스 추천': 257,
#  '대기 번호': 257,
#  '치킨 샐러드': 257,
#  '인테리어 신경': 256,
#  '매장 자리': 256,
#  '기회 방문': 255,
#  '저녁 예약': 255,
#  '와인 추천': 255,
#  '실내 인테리어': 255,
#  '테이블 예약': 255,
#  '아부 소바': 254,
#  '맥주 분위기': 254,
#  '돈가스 튀김': 253,
#  '공간 자리': 253,
#  '깍두기 김치': 253,
#  '버섯 리소토': 253,
#  '갈릭 버터': 253,
#  '유료 주차장': 253,
#  '사진 음식': 252,
#  '공간 카페': 252,
#  '마지막 디저트': 252,
#  '오픈 초기': 252,
#  '음식 입맛': 251,
#  '인테리어 소품': 251,
#  '식사 주문': 251,
#  '소금 고추냉이': 251,
#  '연어 뱃살': 251,
#  '와인 안주': 251,
#  '방문 기억': 251,
#  '최고 방문': 251,
#  '가지 볶음': 251,
#  '음료 분위기': 250,
#  '주문 포장': 250,
#  '정식 메뉴': 250,
#  '메뉴 처음': 250,
#  '생각 식사': 250,
#  '메뉴 전체': 249,
#  '생각 크림': 249,
#  '위치 사람': 249,
#  '대기 사람': 249,
#  '인스타 사진': 249,
#  '생선 요리': 249,
#  '인도 음식': 248,
#  '사람 기분': 248,
#  '애프터 세트': 248,
#  '방문 친구': 248,
#  '국물 짬뽕': 248,
#  '리뷰 기대': 248,
#  '애플 파이': 247,
#  '반찬 다양': 247,
#  '근처 유명': 247,
#  '이국 분위기': 247,
#  ...}

# %%
service_pairs = category_json["service"]
price_pairs = category_json["price"]
food_pairs = category_json["food"]
other_pairs = category_json["other"]

# %%
def quantile_split(pairs, head_q=0.02, mid_q=0.20, min_head=10):
    if not pairs:
        return [], [], []

    # ✅ dict이면 items로 변환
    if isinstance(pairs, dict):
        pairs = list(pairs.items())

    # ✅ 타입 검증
    if isinstance(pairs[0], str):
        raise ValueError("pairs must be [(phrase, count), ...] or dict{phrase:count}")

    pairs_sorted = sorted(pairs, key=lambda x: x[1], reverse=True)
    n = len(pairs_sorted)

    head_n = max(min_head, int(n * head_q))
    head_n = min(head_n, n)

    mid_end = int(n * mid_q)
    mid_end = max(mid_end, head_n)
    mid_end = min(mid_end, n)

    head = pairs_sorted[:head_n]
    mid  = pairs_sorted[head_n:mid_end]
    tail = pairs_sorted[mid_end:]
    return head, mid, tail

pairs_list = [service_pairs, price_pairs, food_pairs, other_pairs]
pairs_name = ["service", "price", "food", "other"]

for name, pairs in zip(pairs_name,pairs_list):
    head, mid, tail = quantile_split(pairs, head_q=0.02, mid_q=0.20, min_head=10)

    print(f"\n===== {name} =====")
    print(f"n={len(pairs)} | head={len(head)} | mid={len(mid)} | tail={len(tail)}")

    print("\n[HEAD]")
    print(head[:20])   # 너무 길면 일부만

    print("\n[MID]")
    print(mid[:20])

    print("\n[TAIL]")
    print(tail[:20])
# Out:
# ===== service =====
# n=142 | head=10 | mid=18 | tail=114
#
# [HEAD]
# [('직원 친절', 14700), ('사장 친절', 8028), ('친절 음식', 1932), ('친절 기분', 1910), ('서비스 친절', 1802), ('친절 서비스', 1502), ('분위기 서비스', 1236), ('사장 직원', 1078), ('친절 사장', 1042), ('직원 서비스', 1038)]
#
# [MID]
# [('친절 직원', 1005), ('음식 서비스', 983), ('친절 방문', 979), ('가격 서비스', 946), ('친절 가격', 945), ('친절 분위기', 940), ('서비스 만족', 867), ('서비스 분위기', 857), ('분위기 친절', 805), ('분위기 직원', 776), ('친절 설명', 760), ('친절 고기', 741), ('종업원 친절', 735), ('서비스 음식', 729), ('아주머니 친절', 728), ('음식 직원', 707), ('서비스 최악', 655), ('서버 친절', 617)]
#
# [TAIL]
# [('친절 가게', 608), ('주인 친절', 589), ('고기 직원', 572), ('가격 친절', 570), ('서비스 가격', 568), ('서빙 친절', 558), ('아르바이트 친절', 545), ('음식 친절', 533), ('이모 친절', 518), ('남자 직원', 509), ('셰프 친절', 508), ('직원 교육', 508), ('서비스 최고', 491), ('친절 응대', 486), ('친절 메뉴', 472), ('친절 만족', 471), ('사람 친절', 470), ('사람 직원', 457), ('서비스 기대', 452), ('친절 커피', 452)]
#
# ===== price =====
# n=118 | head=10 | mid=13 | tail=95
#
# [HEAD]
# [('가격 대비', 10120), ('무한 리필', 3737), ('가격 생각', 2993), ('음식 가격', 1582), ('합리 가격', 1412), ('생각 가격', 1371), ('분위기 가격', 1347), ('메뉴 가격', 1340), ('가격 만족', 1209), ('가격 분위기', 1206)]
#
# [MID]
# [('가격 합리', 1204), ('가격 부담', 1202), ('가격 음식', 1168), ('리필 가능', 1157), ('커피 가격', 1010), ('고기 가격', 952), ('가격 서비스', 946), ('친절 가격', 945), ('가격 퀄리티', 937), ('가격 구성비', 916), ('가격 사악', 896), ('가격 고기', 880), ('음료 가격', 820)]
#
# [TAIL]
# [('주문 가격', 690), ('가격 방문', 686), ('대비 만족', 677), ('가격 메뉴', 649), ('부담 가격', 605), ('방문 가격', 586), ('가격 친절', 570), ('반찬 리필', 569), ('서비스 가격', 568), ('대비 가격', 510), ('파스타 가격', 488), ('만족 가격', 481), ('사람 가격', 472), ('가격 커피', 463), ('구성비 가격', 462), ('식당 가격', 458), ('추천 가격', 446), ('퀄리티 가격', 440), ('가격 사람', 417), ('최고 가격', 412)]
#
# ===== food =====
# n=395 | head=10 | mid=69 | tail=316
#
# [HEAD]
# [('가락 국수', 7196), ('평양 냉면', 6134), ('수제 버거', 3433), ('크림 치즈', 3052), ('치즈 케이크', 3035), ('크림 파스타', 2955), ('당근 케이크', 1632), ('오일 파스타', 1498), ('카페 커피', 1494), ('비빔 냉면', 1452)]
#
# [MID]
# [('치즈 버거', 1451), ('리코타 치즈', 1418), ('화덕 피자', 1404), ('드립 커피', 1402), ('피자 파스타', 1398), ('로제 파스타', 1336), ('국물 고기', 1333), ('국수 국물', 1332), ('분위기 커피', 1315), ('고기 국물', 1309), ('고기 국수', 1253), ('고기 냄새', 1228), ('피자 도우', 1226), ('파스타 피자', 1168), ('치즈 돈가스', 1140), ('고기 만두', 1107), ('커피 디저트', 1098), ('커피 가격', 1010), ('비빔 막국수', 1003), ('고기 소스', 1001)]
#
# [TAIL]
# [('파스타 크림', 605), ('케이크 커피', 603), ('치즈 소스', 591), ('디저트 커피', 581), ('고기 생각', 577), ('고기 직원', 572), ('머리 고기', 570), ('돈가스 고기', 569), ('토마토 파스타', 568), ('커피 주문', 567), ('모차렐라 치즈', 566), ('야채 고기', 557), ('케이크 크림', 547), ('케이크 종류', 546), ('해물 칼국수', 544), ('커피 메뉴', 542), ('국수 고기', 539), ('초코 케이크', 538), ('고기 김치', 537), ('고기 추가', 536)]
#
# ===== other =====
# n=1373 | head=27 | mid=247 | tail=1099
#
# [HEAD]
# [('방문 의사', 7897), ('남자 친구', 2866), ('새우 튀김', 2843), ('종류 다양', 2607), ('주차 공간', 2359), ('주문 메뉴', 2235), ('간장 게장', 2224), ('여자 친구', 2185), ('세트 메뉴', 2172), ('메뉴 주문', 2153), ('가게 분위기', 2149), ('분위기 음식', 2126), ('시그니처 메뉴', 2100), ('카페 분위기', 1991), ('대표 메뉴', 1949), ('플랫 화이트', 1865), ('메뉴 다양', 1845), ('브레이크 타임', 1834), ('테이블 간격', 1832), ('만족 식사', 1791)]
#
# [MID]
# [('추천 메뉴', 1661), ('방문 추천', 1652), ('생선 구이', 1649), ('마제 소바', 1640), ('주차 가능', 1607), ('가게 내부', 1527), ('크림 소스', 1521), ('망고 플레이트', 1516), ('평일 저녁', 1503), ('분위기 카페', 1490), ('주문 음식', 1463), ('사리 추가', 1463), ('육회 비빔밥', 1450), ('짬뽕 국물', 1435), ('메인 메뉴', 1412), ('순대 국밥', 1407), ('기대 실망', 1351), ('평일 점심', 1346), ('메뉴 구성', 1309), ('개인 취향', 1308)]
#
# [TAIL]
# [('기본 메뉴', 538), ('망고 하이', 534), ('유명 카페', 534), ('전반 만족', 534), ('돼지 갈비', 534), ('포장 주문', 533), ('개인 생각', 530), ('주차 불편', 530), ('마늘 바게트', 528), ('주차장 이용', 527), ('선지 해장국', 527), ('웨이팅 생각', 527), ('오픈 주방', 527), ('평일 웨이팅', 525), ('가게 테이블', 525), ('음식 메뉴', 525), ('회사 근처', 524), ('카페 방문', 524), ('음식 추천', 518), ('사람 입맛', 518)]

# %%
import random, math

def pick_seeds(head, mid, tail, mid_k=5, tail_k=1, seed=42):
    random.seed(seed)

    # head는 전부 포함
    seeds = [p for p, _ in head]

    # mid는 가중 샘플링 (log(count))
    if mid:
        weights = [math.log(c + 1) for _, c in mid]
        idxs = list(range(len(mid)))
        for _ in range(min(mid_k, len(mid))):
            total = sum(weights[i] for i in idxs)
            r = random.random() * total
            acc = 0.0
            for i in idxs:
                acc += weights[i]
                if acc >= r:
                    seeds.append(mid[i][0])
                    idxs.remove(i)
                    break

    # tail은 랜덤 (탐색용)
    if tail and tail_k > 0:
        picks = random.sample(tail, k=min(tail_k, len(tail)))
        seeds.extend([p for p, _ in picks])

    # 중복 제거(순서 유지)
    seen = set()
    seeds = [s for s in seeds if not (s in seen or seen.add(s))]

    return seeds

# %%
seeds_list = []
for name, pairs in zip(pairs_name, pairs_list):
    head, mid, tail = quantile_split(pairs)
    seeds = pick_seeds(head, mid, tail, mid_k=5, tail_k=1)

    print(f"\n{name} seeds ({len(seeds)}):")
    print(seeds)
    seeds_list.append(seeds)
# Out:
# service seeds (16):
# ['직원 친절', '사장 친절', '친절 음식', '친절 기분', '서비스 친절', '친절 서비스', '분위기 서비스', '사장 직원', '친절 사장', '직원 서비스', '친절 고기', '친절 직원', '친절 분위기', '친절 가격', '아주머니 친절', '깔끔 친절']
#
# price seeds (16):
# ['가격 대비', '무한 리필', '가격 생각', '음식 가격', '합리 가격', '생각 가격', '분위기 가격', '메뉴 가격', '가격 만족', '가격 분위기', '가격 퀄리티', '가격 합리', '리필 가능', '커피 가격', '가격 사악', '런치 가격']
#
# food seeds (16):
# ['가락 국수', '평양 냉면', '수제 버거', '크림 치즈', '치즈 케이크', '크림 파스타', '당근 케이크', '오일 파스타', '카페 커피', '비빔 냉면', '커피 원두', '리코타 치즈', '비빔 막국수', '치즈 돈가스', '커피 산미', '치즈 파스타']
#
# other seeds (33):
# ['방문 의사', '남자 친구', '새우 튀김', '종류 다양', '주차 공간', '주문 메뉴', '간장 게장', '여자 친구', '세트 메뉴', '메뉴 주문', '가게 분위기', '분위기 음식', '시그니처 메뉴', '카페 분위기', '대표 메뉴', '플랫 화이트', '메뉴 다양', '브레이크 타임', '테이블 간격', '만족 식사', '추가 주문', '사이드 메뉴', '취향 저격', '토마토 소스', '구성비 최고', '주문 가능', '코스 요리', '만족 방문', '가게 내부', '예약 필수', '김치 만두', '방문 만족', '카페 자리']

# %%
def dedup_reversed_bigrams(bigrams):
    seen = set()
    result = []

    for bg in bigrams:
        a, b = bg.split()
        key = tuple(sorted([a, b]))  # 순서 무시용 canonical key

        if key not in seen:
            seen.add(key)
            result.append(bg)

    return result

# %%
service_name_list = ["service","price","food","other"]

all_seeds = {
    "service": {},
    "price": {},
    "food": {},
    "other": {},
}

for seed, name in zip(seeds_list, service_name_list):
    cleaned = dedup_reversed_bigrams(seed)
    all_seeds[name] = cleaned

print(all_seeds["service"])
print(all_seeds["price"])
print(all_seeds["food"])
print(all_seeds["other"])
# Out:
# ['직원 친절', '사장 친절', '친절 음식', '친절 기분', '서비스 친절', '분위기 서비스', '사장 직원', '직원 서비스', '친절 고기', '친절 분위기', '친절 가격', '아주머니 친절', '깔끔 친절']
# ['가격 대비', '무한 리필', '가격 생각', '음식 가격', '합리 가격', '분위기 가격', '메뉴 가격', '가격 만족', '가격 퀄리티', '리필 가능', '커피 가격', '가격 사악', '런치 가격']
# ['가락 국수', '평양 냉면', '수제 버거', '크림 치즈', '치즈 케이크', '크림 파스타', '당근 케이크', '오일 파스타', '카페 커피', '비빔 냉면', '커피 원두', '리코타 치즈', '비빔 막국수', '치즈 돈가스', '커피 산미', '치즈 파스타']
# ['방문 의사', '남자 친구', '새우 튀김', '종류 다양', '주차 공간', '주문 메뉴', '간장 게장', '여자 친구', '세트 메뉴', '가게 분위기', '분위기 음식', '시그니처 메뉴', '카페 분위기', '대표 메뉴', '플랫 화이트', '메뉴 다양', '브레이크 타임', '테이블 간격', '만족 식사', '추가 주문', '사이드 메뉴', '취향 저격', '토마토 소스', '구성비 최고', '주문 가능', '코스 요리', '만족 방문', '가게 내부', '예약 필수', '김치 만두', '카페 자리']

# %% [markdown]
# service_seeds = ['직원 친절', '사장 친절', '친절 기분', '서비스 친절', '사장 직원', '직원 서비스', '아주머니 친절']
# price_seeds = ['가격 대비', '무한 리필', '가격 생각', '음식 가격', '합리 가격', '메뉴 가격', '가격 만족', '가격 퀄리티', '리필 가능', '커피 가격', '가격 사악', '런치 가격']
# food_seeds = ['가락 국수', '평양 냉면', '수제 버거', '크림 치즈', '치즈 케이크', '크림 파스타', '당근 케이크', '오일 파스타', '카페 커피', '비빔 냉면', '커피 원두', '리코타 치즈', '비빔 막국수', '치즈 돈가스', '커피 산미', '치즈 파스타']

# %% [markdown]
# ## (phrase, count) 버전 - 비중 구하기 (전체 음식점 리뷰 기준 kr3)

# %%
service_pairs = category_json["service"]
price_pairs = category_json["price"]
food_pairs = category_json["food"]
other_pairs = category_json["other"]

# %%
def quantile_split(pairs, head_q=0.02, mid_q=0.20, min_head=10):
    if not pairs:
        return [], [], []

    # ✅ dict이면 items로 변환
    if isinstance(pairs, dict):
        pairs = list(pairs.items())

    # ✅ 타입 검증
    if isinstance(pairs[0], str):
        raise ValueError("pairs must be [(phrase, count), ...] or dict{phrase:count}")

    pairs_sorted = sorted(pairs, key=lambda x: x[1], reverse=True)
    n = len(pairs_sorted)

    head_n = max(min_head, int(n * head_q))
    head_n = min(head_n, n)

    mid_end = int(n * mid_q)
    mid_end = max(mid_end, head_n)
    mid_end = min(mid_end, n)

    head = pairs_sorted[:head_n]
    mid  = pairs_sorted[head_n:mid_end]
    tail = pairs_sorted[mid_end:]
    return head, mid, tail

pairs_list = [service_pairs, price_pairs, food_pairs, other_pairs]
pairs_name = ["service", "price", "food", "other"]

for name, pairs in zip(pairs_name,pairs_list):
    head, mid, tail = quantile_split(pairs, head_q=0.02, mid_q=0.20, min_head=10)

    print(f"\n===== {name} =====")
    print(f"n={len(pairs)} | head={len(head)} | mid={len(mid)} | tail={len(tail)}")

    print("\n[HEAD]")
    print(head[:20])   # 너무 길면 일부만

    print("\n[MID]")
    print(mid[:20])

    print("\n[TAIL]")
    print(tail[:20])
# Out:
# ===== service =====
# n=142 | head=10 | mid=18 | tail=114
#
# [HEAD]
# [('직원 친절', 14700), ('사장 친절', 8028), ('친절 음식', 1932), ('친절 기분', 1910), ('서비스 친절', 1802), ('친절 서비스', 1502), ('분위기 서비스', 1236), ('사장 직원', 1078), ('친절 사장', 1042), ('직원 서비스', 1038)]
#
# [MID]
# [('친절 직원', 1005), ('음식 서비스', 983), ('친절 방문', 979), ('가격 서비스', 946), ('친절 가격', 945), ('친절 분위기', 940), ('서비스 만족', 867), ('서비스 분위기', 857), ('분위기 친절', 805), ('분위기 직원', 776), ('친절 설명', 760), ('친절 고기', 741), ('종업원 친절', 735), ('서비스 음식', 729), ('아주머니 친절', 728), ('음식 직원', 707), ('서비스 최악', 655), ('서버 친절', 617)]
#
# [TAIL]
# [('친절 가게', 608), ('주인 친절', 589), ('고기 직원', 572), ('가격 친절', 570), ('서비스 가격', 568), ('서빙 친절', 558), ('아르바이트 친절', 545), ('음식 친절', 533), ('이모 친절', 518), ('남자 직원', 509), ('셰프 친절', 508), ('직원 교육', 508), ('서비스 최고', 491), ('친절 응대', 486), ('친절 메뉴', 472), ('친절 만족', 471), ('사람 친절', 470), ('사람 직원', 457), ('서비스 기대', 452), ('친절 커피', 452)]
#
# ===== price =====
# n=118 | head=10 | mid=13 | tail=95
#
# [HEAD]
# [('가격 대비', 10120), ('무한 리필', 3737), ('가격 생각', 2993), ('음식 가격', 1582), ('합리 가격', 1412), ('생각 가격', 1371), ('분위기 가격', 1347), ('메뉴 가격', 1340), ('가격 만족', 1209), ('가격 분위기', 1206)]
#
# [MID]
# [('가격 합리', 1204), ('가격 부담', 1202), ('가격 음식', 1168), ('리필 가능', 1157), ('커피 가격', 1010), ('고기 가격', 952), ('가격 서비스', 946), ('친절 가격', 945), ('가격 퀄리티', 937), ('가격 구성비', 916), ('가격 사악', 896), ('가격 고기', 880), ('음료 가격', 820)]
#
# [TAIL]
# [('주문 가격', 690), ('가격 방문', 686), ('대비 만족', 677), ('가격 메뉴', 649), ('부담 가격', 605), ('방문 가격', 586), ('가격 친절', 570), ('반찬 리필', 569), ('서비스 가격', 568), ('대비 가격', 510), ('파스타 가격', 488), ('만족 가격', 481), ('사람 가격', 472), ('가격 커피', 463), ('구성비 가격', 462), ('식당 가격', 458), ('추천 가격', 446), ('퀄리티 가격', 440), ('가격 사람', 417), ('최고 가격', 412)]
#
# ===== food =====
# n=395 | head=10 | mid=69 | tail=316
#
# [HEAD]
# [('가락 국수', 7196), ('평양 냉면', 6134), ('수제 버거', 3433), ('크림 치즈', 3052), ('치즈 케이크', 3035), ('크림 파스타', 2955), ('당근 케이크', 1632), ('오일 파스타', 1498), ('카페 커피', 1494), ('비빔 냉면', 1452)]
#
# [MID]
# [('치즈 버거', 1451), ('리코타 치즈', 1418), ('화덕 피자', 1404), ('드립 커피', 1402), ('피자 파스타', 1398), ('로제 파스타', 1336), ('국물 고기', 1333), ('국수 국물', 1332), ('분위기 커피', 1315), ('고기 국물', 1309), ('고기 국수', 1253), ('고기 냄새', 1228), ('피자 도우', 1226), ('파스타 피자', 1168), ('치즈 돈가스', 1140), ('고기 만두', 1107), ('커피 디저트', 1098), ('커피 가격', 1010), ('비빔 막국수', 1003), ('고기 소스', 1001)]
#
# [TAIL]
# [('파스타 크림', 605), ('케이크 커피', 603), ('치즈 소스', 591), ('디저트 커피', 581), ('고기 생각', 577), ('고기 직원', 572), ('머리 고기', 570), ('돈가스 고기', 569), ('토마토 파스타', 568), ('커피 주문', 567), ('모차렐라 치즈', 566), ('야채 고기', 557), ('케이크 크림', 547), ('케이크 종류', 546), ('해물 칼국수', 544), ('커피 메뉴', 542), ('국수 고기', 539), ('초코 케이크', 538), ('고기 김치', 537), ('고기 추가', 536)]
#
# ===== other =====
# n=1373 | head=27 | mid=247 | tail=1099
#
# [HEAD]
# [('방문 의사', 7897), ('남자 친구', 2866), ('새우 튀김', 2843), ('종류 다양', 2607), ('주차 공간', 2359), ('주문 메뉴', 2235), ('간장 게장', 2224), ('여자 친구', 2185), ('세트 메뉴', 2172), ('메뉴 주문', 2153), ('가게 분위기', 2149), ('분위기 음식', 2126), ('시그니처 메뉴', 2100), ('카페 분위기', 1991), ('대표 메뉴', 1949), ('플랫 화이트', 1865), ('메뉴 다양', 1845), ('브레이크 타임', 1834), ('테이블 간격', 1832), ('만족 식사', 1791)]
#
# [MID]
# [('추천 메뉴', 1661), ('방문 추천', 1652), ('생선 구이', 1649), ('마제 소바', 1640), ('주차 가능', 1607), ('가게 내부', 1527), ('크림 소스', 1521), ('망고 플레이트', 1516), ('평일 저녁', 1503), ('분위기 카페', 1490), ('주문 음식', 1463), ('사리 추가', 1463), ('육회 비빔밥', 1450), ('짬뽕 국물', 1435), ('메인 메뉴', 1412), ('순대 국밥', 1407), ('기대 실망', 1351), ('평일 점심', 1346), ('메뉴 구성', 1309), ('개인 취향', 1308)]
#
# [TAIL]
# [('기본 메뉴', 538), ('망고 하이', 534), ('유명 카페', 534), ('전반 만족', 534), ('돼지 갈비', 534), ('포장 주문', 533), ('개인 생각', 530), ('주차 불편', 530), ('마늘 바게트', 528), ('주차장 이용', 527), ('선지 해장국', 527), ('웨이팅 생각', 527), ('오픈 주방', 527), ('평일 웨이팅', 525), ('가게 테이블', 525), ('음식 메뉴', 525), ('회사 근처', 524), ('카페 방문', 524), ('음식 추천', 518), ('사람 입맛', 518)]

# %%
import random, math

def pick_seeds_pairs(head, mid, tail, mid_k=5, tail_k=1, seed=42):
    random.seed(seed)

    # ✅ head는 전부 포함 (p,c) 그대로
    seeds = list(head)

    # ✅ mid는 가중 샘플링 (log(count))
    if mid:
        idxs = list(range(len(mid)))
        weights = [math.log(c + 1) for _, c in mid]

        for _ in range(min(mid_k, len(mid))):
            total = sum(weights[i] for i in idxs)
            r = random.random() * total
            acc = 0.0
            for i in idxs:
                acc += weights[i]
                if acc >= r:
                    seeds.append(mid[i])   # ✅ (p,c) 그대로
                    idxs.remove(i)
                    break

    # ✅ tail은 랜덤 (탐색용)
    if tail and tail_k > 0:
        picks = random.sample(tail, k=min(tail_k, len(tail)))
        seeds.extend(picks)  # ✅ (p,c) 그대로

    # ✅ 중복 제거(phrase 기준, 순서 유지)
    seen = set()
    out = []
    for p, c in seeds:
        if p not in seen:
            out.append((p, c))
            seen.add(p)

    return out

# %%
def dedup_reversed_bigrams_pairs(pairs):
    # pairs: [( "a b", count ), ...]
    order = []         # canonical key의 등장 순서 유지
    agg = {}           # canonical key -> {"repr":원문표현, "count":합}

    for phrase, cnt in pairs:
        a, b = phrase.split()
        key = tuple(sorted([a, b]))  # 순서 무시용 canonical key

        if key not in agg:
            agg[key] = {"repr": phrase, "count": cnt}
            order.append(key)
        else:
            agg[key]["count"] += cnt  # ✅ 합산 (원하면 max로 변경 가능)

    return [(agg[k]["repr"], agg[k]["count"]) for k in order]

# %%
seeds_list = []
for name, pairs in zip(pairs_name, pairs_list):
    head, mid, tail = quantile_split(pairs)

    seeds = pick_seeds_pairs(head, mid, tail, mid_k=5, tail_k=1)  # ✅ 변경

    print(f"\n{name} seeds ({len(seeds)}):")
    print(seeds)
    seeds_list.append(seeds)

service_name_list = ["service","price","food","other"]

all_seeds = {}
for seed_pairs, name in zip(seeds_list, service_name_list):
    cleaned = dedup_reversed_bigrams_pairs(seed_pairs)  # ✅ 변경
    all_seeds[name] = cleaned

print(all_seeds["service"])
print(all_seeds["price"])
print(all_seeds["food"])
print(all_seeds["other"])
# Out:
# service seeds (16):
# [('직원 친절', 14700), ('사장 친절', 8028), ('친절 음식', 1932), ('친절 기분', 1910), ('서비스 친절', 1802), ('친절 서비스', 1502), ('분위기 서비스', 1236), ('사장 직원', 1078), ('친절 사장', 1042), ('직원 서비스', 1038), ('친절 고기', 741), ('친절 직원', 1005), ('친절 분위기', 940), ('친절 가격', 945), ('아주머니 친절', 728), ('깔끔 친절', 231)]
#
# price seeds (16):
# [('가격 대비', 10120), ('무한 리필', 3737), ('가격 생각', 2993), ('음식 가격', 1582), ('합리 가격', 1412), ('생각 가격', 1371), ('분위기 가격', 1347), ('메뉴 가격', 1340), ('가격 만족', 1209), ('가격 분위기', 1206), ('가격 퀄리티', 937), ('가격 합리', 1204), ('리필 가능', 1157), ('커피 가격', 1010), ('가격 사악', 896), ('런치 가격', 212)]
#
# food seeds (16):
# [('가락 국수', 7196), ('평양 냉면', 6134), ('수제 버거', 3433), ('크림 치즈', 3052), ('치즈 케이크', 3035), ('크림 파스타', 2955), ('당근 케이크', 1632), ('오일 파스타', 1498), ('카페 커피', 1494), ('비빔 냉면', 1452), ('커피 원두', 749), ('리코타 치즈', 1418), ('비빔 막국수', 1003), ('치즈 돈가스', 1140), ('커피 산미', 718), ('치즈 파스타', 215)]
#
# other seeds (33):
# [('방문 의사', 7897), ('남자 친구', 2866), ('새우 튀김', 2843), ('종류 다양', 2607), ('주차 공간', 2359), ('주문 메뉴', 2235), ('간장 게장', 2224), ('여자 친구', 2185), ('세트 메뉴', 2172), ('메뉴 주문', 2153), ('가게 분위기', 2149), ('분위기 음식', 2126), ('시그니처 메뉴', 2100), ('카페 분위기', 1991), ('대표 메뉴', 1949), ('플랫 화이트', 1865), ('메뉴 다양', 1845), ('브레이크 타임', 1834), ('테이블 간격', 1832), ('만족 식사', 1791), ('추가 주문', 1760), ('사이드 메뉴', 1742), ('취향 저격', 1724), ('토마토 소스', 1700), ('구성비 최고', 1691), ('주문 가능', 1690), ('코스 요리', 1689), ('만족 방문', 673), ('가게 내부', 1527), ('예약 필수', 941), ('김치 만두', 1011), ('방문 만족', 633), ('카페 자리', 412)]
# [('직원 친절', 15705), ('사장 친절', 9070), ('친절 음식', 1932), ('친절 기분', 1910), ('서비스 친절', 3304), ('분위기 서비스', 1236), ('사장 직원', 1078), ('직원 서비스', 1038), ('친절 고기', 741), ('친절 분위기', 940), ('친절 가격', 945), ('아주머니 친절', 728), ('깔끔 친절', 231)]
# [('가격 대비', 10120), ('무한 리필', 3737), ('가격 생각', 4364), ('음식 가격', 1582), ('합리 가격', 2616), ('분위기 가격', 2553), ('메뉴 가격', 1340), ('가격 만족', 1209), ('가격 퀄리티', 937), ('리필 가능', 1157), ('커피 가격', 1010), ('가격 사악', 896), ('런치 가격', 212)]
# [('가락 국수', 7196), ('평양 냉면', 6134), ('수제 버거', 3433), ('크림 치즈', 3052), ('치즈 케이크', 3035), ('크림 파스타', 2955), ('당근 케이크', 1632), ('오일 파스타', 1498), ('카페 커피', 1494), ('비빔 냉면', 1452), ('커피 원두', 749), ('리코타 치즈', 1418), ('비빔 막국수', 1003), ('치즈 돈가스', 1140), ('커피 산미', 718), ('치즈 파스타', 215)]
# [('방문 의사', 7897), ('남자 친구', 2866), ('새우 튀김', 2843), ('종류 다양', 2607), ('주차 공간', 2359), ('주문 메뉴', 4388), ('간장 게장', 2224), ('여자 친구', 2185), ('세트 메뉴', 2172), ('가게 분위기', 2149), ('분위기 음식', 2126), ('시그니처 메뉴', 2100), ('카페 분위기', 1991), ('대표 메뉴', 1949), ('플랫 화이트', 1865), ('메뉴 다양', 1845), ('브레이크 타임', 1834), ('테이블 간격', 1832), ('만족 식사', 1791), ('추가 주문', 1760), ('사이드 메뉴', 1742), ('취향 저격', 1724), ('토마토 소스', 1700), ('구성비 최고', 1691), ('주문 가능', 1690), ('코스 요리', 1689), ('만족 방문', 1306), ('가게 내부', 1527), ('예약 필수', 941), ('김치 만두', 1011), ('카페 자리', 412)]

# %%
service_pairs = all_seeds["service"]
price_pairs = all_seeds["price"]
food_pairs = all_seeds["food"]
other_pairs = all_seeds["other"]

# %%
def sum_counts(pairs):
    return sum(cnt for _, cnt in pairs)

# %%
pairs_list = [service_pairs, price_pairs, food_pairs, other_pairs]
pairs_name = ["service", "price", "food", "other"]

total_by_category = {}

for name, pairs in zip(pairs_name, pairs_list):
    total = sum_counts(pairs)
    total_by_category[name] = total
    print(f"{name}: {total}")
# Out:
# service: 38858
# price: 31733
# food: 37124
# other: 66216

# %%
total_count = sum(total_by_category.values())
service_count = total_by_category["service"]
price_count = total_by_category["price"]
food_count = total_by_category["food"]
other_count = total_by_category["other"]
print("각 카테고리별 빈도: ",total_by_category)
print("총 빈도: ",total_count)

service_ratio = service_count / total_count
service_ratio = round(service_ratio, 2)
print("서비스 비중: ",service_ratio)
price_ratio = price_count / total_count
price_ratio = round(price_ratio, 2)
print("가격 비중: ",price_ratio)
food_ratio = food_count / total_count
food_ratio = round(food_ratio, 2)
print("음식 비중: ",food_ratio)
other_ratio = other_count / total_count
other_ratio = round(other_ratio, 2)
print("기타 비중: ",other_ratio)
# Out:
# 각 카테고리별 빈도:  {'service': 38858, 'price': 31733, 'food': 37124, 'other': 66216}
# 총 빈도:  173931
# 서비스 비중:  0.22
# 가격 비중:  0.18
# 음식 비중:  0.21
# 기타 비중:  0.38
